# %% [markdown]
# # Correlación entre contaminantes

# %% [markdown]
# Se hace la correlación cruzada (cross correlation) entre los distintos contaminantes. Se saca un promedio de todas las estaciones.

# %%
# Se importan bibliotecas necesarias

from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from pandas.plotting import scatter_matrix

os.chdir("/home/pradel/Desktop/Forecast_CDMX_pollution/datasets/por_hora")

# %%
# Se importa el archivo csv con los datos usando pandas

data = pd.read_csv("/home/pradel/Desktop/Forecast_CDMX_pollution/datasets/por_hora/cont_hora_todos.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                fecha  hora  dia  mes id_station  UVA  UVB  PA  \
# 0           0  2014-01-01 01:00:00     1    1    1        ACO  NaN  NaN NaN
# 1           1  2014-01-01 01:00:00     1    1    1        ATI  NaN  NaN NaN
# 2           2  2014-01-01 01:00:00     1    1    1        CAM  NaN  NaN NaN
# 3           3  2014-01-01 01:00:00     1    1    1        CHO  NaN  NaN NaN
# 4           5  2014-01-01 01:00:00     1    1    1        CUA  NaN  NaN NaN
#
#     CO  ...   NOX   O3  PM2.5  PMCO   SO2    RH  TMP  WSP    WDR  PM10
# 0  0.3  ...   NaN  9.0    NaN   NaN   2.0  89.0  6.8  2.5  323.0  57.0
# 1  0.5  ...  20.0  9.0    NaN   NaN   4.0   NaN  NaN  NaN    NaN  69.0
# 2  0.5  ...  34.0  5.0   54.0  15.0  14.0   NaN  NaN  NaN    NaN  69.0
# 3  NaN  ...   NaN  2.0    NaN   NaN   5.0  84.0  9.4  1.1   61.0  84.0
# 4  1.3  ...  54.0  4.0    NaN   NaN  11.0  83.0  7.5  1.3  168.0  83.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Estructuración del dataframe

# %%
data.drop(['Unnamed: 0', 'mes', 'dia', 'hora'], axis=1, inplace = True)
data.head()
# Out:
#                  fecha id_station  UVA  UVB  PA   CO    NO   NO2   NOX   O3  \
# 0  2014-01-01 01:00:00        ACO  NaN  NaN NaN  0.3   NaN   NaN   NaN  9.0
# 1  2014-01-01 01:00:00        ATI  NaN  NaN NaN  0.5   2.0  18.0  20.0  9.0
# 2  2014-01-01 01:00:00        CAM  NaN  NaN NaN  0.5   7.0  27.0  34.0  5.0
# 3  2014-01-01 01:00:00        CHO  NaN  NaN NaN  NaN   NaN   NaN   NaN  2.0
# 4  2014-01-01 01:00:00        CUA  NaN  NaN NaN  1.3  17.0  37.0  54.0  4.0
#
#    PM2.5  PMCO   SO2    RH  TMP  WSP    WDR  PM10
# 0    NaN   NaN   2.0  89.0  6.8  2.5  323.0  57.0
# 1    NaN   NaN   4.0   NaN  NaN  NaN    NaN  69.0
# 2   54.0  15.0  14.0   NaN  NaN  NaN    NaN  69.0
# 3    NaN   NaN   5.0  84.0  9.4  1.1   61.0  84.0
# 4    NaN   NaN  11.0  83.0  7.5  1.3  168.0  83.0

# %%
data = data.sort_values(by='fecha')

# %%
data = data.reset_index(drop = True)

# %%
data.head()
# Out:
#                  fecha id_station  UVA  UVB  PA   CO   NO   NO2   NOX    O3  \
# 0  2012-01-01 00:00:00        ACO  NaN  NaN NaN  0.1  1.0   4.0   4.0  24.0
# 1  2012-01-01 00:00:00        TLA  0.0  0.0 NaN  0.2  7.0  26.0  33.0   8.0
# 2  2012-01-01 00:00:00        XAL  NaN  NaN NaN  0.1  6.0  12.0  18.0  19.0
# 3  2012-01-01 00:00:00        TAH  NaN  NaN NaN  0.7  2.0  15.0  18.0  10.0
# 4  2012-01-01 00:00:00        SUR  NaN  NaN NaN  0.5  NaN   NaN   NaN  13.0
#
#    PM2.5  PMCO  SO2    RH   TMP  WSP    WDR  PM10
# 0    NaN   NaN  1.0  71.0  10.9  3.8   30.0   6.0
# 1    9.0   7.0  4.0  71.0  11.5  2.5  346.0  16.0
# 2   10.0   5.0  1.0  66.0  11.8  NaN    NaN  15.0
# 3    NaN   NaN  1.0  73.0   9.9  NaN    NaN  23.0
# 4    NaN   NaN  3.0  65.0  12.5  3.0  317.0  13.0

# %% [markdown]
# ## Correlación entre los contaminantes

# %%
data = data.groupby('fecha', as_index = False).mean()

# %%
data = data.round(1)
data.head(5)
# Out:
#                  fecha  UVA  UVB     PA   CO    NO   NO2   NOX    O3  PM2.5  \
# 0  2012-01-01 00:00:00  0.0  0.0  590.0  0.3   2.6  13.8  16.2  15.1    9.4
# 1  2012-01-01 01:00:00  0.0  0.0  587.0  1.4  30.0  39.8  69.5   5.5   77.0
# 2  2012-01-01 02:00:00  0.0  0.0  587.0  1.7  39.7  40.0  79.6   4.3  121.0
# 3  2012-01-01 03:00:00  0.0  0.0  587.0  1.8  40.8  39.1  79.6   4.6  125.1
# 4  2012-01-01 04:00:00  0.0  0.0  587.0  2.0  51.2  37.8  88.9   4.1  129.6
#
#     PMCO  SO2    RH   TMP  WSP    WDR   PM10
# 0    6.3  1.6  68.3  11.4  3.2  294.9   14.8
# 1  136.9  7.2  68.8   9.7  1.4  180.0  174.3
# 2   38.0  8.2  72.6   9.1  1.6  139.6  164.6
# 3   36.7  7.6  74.1   8.6  1.1  232.6  172.9
# 4   37.0  6.9  75.3   8.2  1.0  225.6  167.6

# %% [markdown]
# ## Autocorrelación entre contaminantes

# %%
# Función para hacer el lag
def data_lag(df,lag=0,NON_DER=[]):
    df = df.copy()
    if not lag:
        return df
    cols ={}
    for i in range(1,lag+1):
        for x in list(df.columns):
            if x not in NON_DER:
                if not x in cols:
                    cols[x] = ['{}_{}'.format(x, i)]
                else:
                    cols[x].append('{}_{}'.format(x, i))
    for k,v in cols.items():
        columns = v
        dfn = pd.DataFrame(data=None, columns=columns, index=df.index)    
        i = 1
        for c in columns:
            dfn[c] = df[k].shift(periods=i)
            i+=1
        df = pd.concat([df, dfn], axis=1, join_axes=[df.index])
    return df

# %%
NON_DER = ['date',]

# %%
data_72 = data_lag(data, 72, NON_DER)

# %%
data_72_corr = data_72.corr()

# %% [markdown]
# ## Correlaciones entre PM10 y los demás contaminantes

# %%
PM10_72 = data_72_corr[["PM10"]]
PM10_72.reset_index(inplace=True)

# %%
PM10_72.head()
# Out:
#   index      PM10
# 0   UVA  0.123386
# 1   UVB  0.086847
# 2    PA  0.076456
# 3    CO  0.593283
# 4    NO  0.423978

# %%
hora_cero = PM10_72.loc[0:15]
hora_cero.head()
# Out:
#   index      PM10
# 0   UVA  0.123386
# 1   UVB  0.086847
# 2    PA  0.076456
# 3    CO  0.593283
# 4    NO  0.423978

# %%
hora_72 = PM10_72.loc[16:]
hora_72.head()
# Out:
#     index      PM10
# 16  UVA_1  0.080428
# 17  UVA_2  0.059288
# 18  UVA_3  0.054166
# 19  UVA_4  0.055623
# 20  UVA_5  0.052160

# %%
hora_72.shape
# Out:
# (1152, 2)

# %%
sixteen_equal_dfs_contiguous = \
    {name: group for name, group in hora_72.groupby(np.arange(1152) // 72)}

# %%
sixteen_equal_dfs_contiguous
# Out:
# {0:      index      PM10
#  16   UVA_1  0.080428
#  17   UVA_2  0.059288
#  18   UVA_3  0.054166
#  19   UVA_4  0.055623
#  20   UVA_5  0.052160
#  21   UVA_6  0.034876
#  22   UVA_7 -0.000719
#  23   UVA_8 -0.052856
#  24   UVA_9 -0.115930
#  25  UVA_10 -0.180952
#  26  UVA_11 -0.237134
#  27  UVA_12 -0.275227
#  28  UVA_13 -0.286804
#  29  UVA_14 -0.265479
#  30  UVA_15 -0.209555
#  31  UVA_16 -0.123668
#  32  UVA_17 -0.018581
#  33  UVA_18  0.088786
#  34  UVA_19  0.179283
#  35  UVA_20  0.236901
#  36  UVA_21  0.254140
#  37  UVA_22  0.233910
#  38  UVA_23  0.187841
#  39  UVA_24  0.134139
#  40  UVA_25  0.091404
#  41  UVA_26  0.068179
#  42  UVA_27  0.060532
#  43  UVA_28  0.058931
#  44  UVA_29  0.052635
#  45  UVA_30  0.032191
#  ..     ...       ...
#  58  UVA_43  0.180298
#  59  UVA_44  0.232567
#  60  UVA_45  0.246284
#  61  UVA_46  0.225244
#  62  UVA_47  0.181013
#  63  UVA_48  0.130924
#  64  UVA_49  0.091275
#  65  UVA_50  0.068544
#  66  UVA_51  0.058896
#  67  UVA_52  0.053125
#  68  UVA_53  0.041963
#  69  UVA_54  0.018444
#  70  UVA_55 -0.021275
#  71  UVA_56 -0.074924
#  72  UVA_57 -0.136880
#  73  UVA_58 -0.197187
#  74  UVA_59 -0.245587
#  75  UVA_60 -0.273656
#  76  UVA_61 -0.274805
#  77  UVA_62 -0.245583
#  78  UVA_63 -0.185533
#  79  UVA_64 -0.100300
#  80  UVA_65 -0.000639
#  81  UVA_66  0.097219
#  82  UVA_67  0.175923
#  83  UVA_68  0.222737
#  84  UVA_69  0.233288
#  85  UVA_70  0.211744
#  86  UVA_71  0.169234
#  87  UVA_72  0.121485
#
#  [72 rows x 2 columns], 1:       index      PM10
#  88    UVB_1  0.045564
#  89    UVB_2  0.032666
#  90    UVB_3  0.040756
#  91    UVB_4  0.056312
#  92    UVB_5  0.063476
#  93    UVB_6  0.050496
#  94    UVB_7  0.013445
#  95    UVB_8 -0.042680
#  96    UVB_9 -0.108437
#  97   UVB_10 -0.172774
#  98   UVB_11 -0.226659
#  99   UVB_12 -0.264311
#  100  UVB_13 -0.279563
#  101  UVB_14 -0.264908
#  102  UVB_15 -0.214922
#  103  UVB_16 -0.129197
#  231  PA_72  0.081801
#
#  [72 rows x 2 columns], 3:      index      PM10
#  232   CO_1  0.570232
#  233   CO_2  0.490675
#  234   CO_3  0.389232
#  235   CO_4  0.296713
#  236   CO_5  0.238036
#  237   CO_6  0.223180
#  238   CO_7  0.244199
#  239   CO_8  0.285868
#  240   CO_9  0.329730
#  241  CO_10  0.356326
#  242  CO_11  0.349886
#  243  CO_12  0.308710
#  244  CO_13  0.244283
#  245  CO_14  0.174688
#  246  CO_15  0.114463
#  247  CO_16  0.070698
#  248  CO_17  0.046794
#  249  CO_18  0.046869
#  250  CO_19  0.074664
#  251  CO_20  0.128484
#  252  CO_21  0.206491
#  253  CO_22  0.298163
#  254  CO_23  0.384282
#  255  CO_24  0.432031
#  256  CO_25  0.422797
#  257  CO_26  0.359527
#  258  CO_27  0.280260
#  259  CO_28  0.210060
#  260  CO_29  0.167857
#  261  CO_30  0.162129
#  ..     ...       ...
#  274  CO_43  0.026158
#  275  CO_44  0.078426
#  276  CO_45  0.148506
#  277  CO_46  0.228398
#  278  CO_47  0.302059
#  279  CO_48  0.344368
#  280  CO_49  0.337152
#  281  CO_50  0.286995
#  282  CO_51  0.223091
#  283  CO_52  0.167717
#  284  CO_53  0.137188
#  285  CO_54  0.138356
#  286  CO_55  0.164573
#  287  CO_56  0.202217
#  288  CO_57  0.236505
#  289  CO_58  0.252047
#  290  CO_59  0.238375
#  291  CO_60  0.197035
#  292  CO_61  0.139764
#  293  CO_62  0.081587
#  294  CO_63  0.033602
#  295  CO_64 -0.000226
#  296  CO_65 -0.015054
#  297  CO_66 -0.006700
#  298  CO_67  0.023893
#  299  CO_68  0.076247
#  300  CO_69  0.143806
#  301  CO_70  0.217742
#  302  CO_71  0.284497
#  303  CO_72  0.322760
#
#  [72 rows x 2 columns], 4:      index      PM10
#  304   NO_1  0.463029
#  305   NO_2  0.429512
#  306   NO_3  0.351797
#  307   NO_4  0.263245
#  308   NO_5  0.195251
#  309   NO_6  0.165080
#  310   NO_7  0.170018
#  311   NO_8  0.198543
#  312   NO_9  0.235852
#  313  NO_10  0.261841
#  314  NO_11  0.257336
#  315  NO_12  0.217749
#  316  NO_13  0.154390
#  317  NO_14  0.085594
#  318  NO_15  0.024316
#  319  NO_16 -0.024822
#  320  NO_17 -0.059457
#  321  NO_18 -0.075518
#  322  NO_19 -0.069229
#  323  NO_20 -0.036065
#  324  NO_21  0.029952
#  325  NO_22  0.127685
#  326  NO_23  0.242310
#  327  NO_24  0.336810
#  328  NO_25  0.373198
#  329  NO_26  0.344841
#  330  NO_27  0.282322
#  331  NO_28  0.213137
#  332  NO_29  0.161560
#  333  NO_30  0.141289
#  ..     ...       ...
#  346  NO_43 -0.086483
#  347  NO_44 -0.051498
#  348  NO_45  0.010750
#  349  NO_46  0.098231
#  350  NO_47  0.197497
#  351  NO_48  0.279086
#  352  NO_49  0.309665
#  353  NO_50  0.287948
#  354  NO_51  0.238135
#  355  NO_52  0.183367
#  356  NO_53  0.144296
#  357  NO_54  0.131963
#  358  NO_55  0.144321
#  359  NO_56  0.170087
#  711  PMCO_48  0.491773
#  712  PMCO_49  0.463369
#  713  PMCO_50  0.410109
#  714  PMCO_51  0.350876
#  715  PMCO_52  0.299496
#  716  PMCO_53  0.264492
#  717  PMCO_54  0.247652
#  718  PMCO_55  0.246034
#  719  PMCO_56  0.254471
#  720  PMCO_57  0.267864
#  721  PMCO_58  0.280005
#  722  PMCO_59  0.289123
#  723  PMCO_60  0.294643
#  724  PMCO_61  0.297583
#  725  PMCO_62  0.298054
#  726  PMCO_63  0.294185
#  727  PMCO_64  0.287998
#  728  PMCO_65  0.284001
#  729  PMCO_66  0.289825
#  730  PMCO_67  0.308729
#  731  PMCO_68  0.339980
#  732  PMCO_69  0.378441
#  733  PMCO_70  0.418366
#  734  PMCO_71  0.447648
#  735  PMCO_72  0.450905
#
#  [72 rows x 2 columns], 10:       index      PM10
#  736   SO2_1  0.313123
#  737   SO2_2  0.296921
#  738   SO2_3  0.283695
#  739   SO2_4  0.278228
#  740   SO2_5  0.281921
#  741   SO2_6  0.292559
#  742   SO2_7  0.303902
#  743   SO2_8  0.309302
#  744   SO2_9  0.304407
#  745  SO2_10  0.286177
#  746  SO2_11  0.262263
#  747  SO2_12  0.240907
#  748  SO2_13  0.222435
#  749  SO2_14  0.205650
#  750  SO2_15  0.189107
#  751  SO2_16  0.173046
#  752  SO2_17  0.160521
#  753  SO2_18  0.152742
#  754  SO2_19  0.152374
#  755  SO2_20  0.161440
#  756  SO2_21  0.180790
#  757  SO2_22  0.201454
#  758  SO2_23  0.217663
#  759  SO2_24  0.222175
#  760  SO2_25  0.220794
#  761  SO2_26  0.212650
#  762  SO2_27  0.206091
#  763  SO2_28  0.205090
#  764  SO2_29  0.211053
#  765  SO2_30  0.222047
#  ..      ...       ...
#  778  SO2_43  0.109299
#  779  SO2_44  0.118373
#  780  SO2_45  0.135184
#  781  SO2_46  0.153590
#  782  SO2_47  0.166833
#  783  SO2_48  0.172709
#  784  SO2_49  0.171595
#  785  SO2_50  0.167701
#  786  SO2_51  0.164927
#  787  SO2_52  0.166522
#  788  SO2_53  0.170903
#  789  SO2_54  0.178652
#  790  SO2_55  0.185133
#  791  SO2_56  0.184955
#  792  SO2_57  0.176853
#  793  SO2_58  0.162603
#  794  SO2_59  0.145244
#  795  SO2_60  0.129225
#  796  SO2_61  0.114968
#  797  SO2_62  0.103056
#  798  SO2_63  0.093152
#  799  SO2_64  0.086587
#  800  SO2_65  0.083128
#  801  SO2_66  0.084488
#  802  SO2_67  0.093222
#  803  SO2_68  0.108282
#  804  SO2_69  0.127216
#  805  SO2_70  0.145431
#  806  SO2_71  0.158294
#  807  SO2_72  0.163692
#
#  [72 rows x 2 columns], 11:      index      PM10
#  808   RH_1 -0.366051
#  809   RH_2 -0.336802
#  810   RH_3 -0.309821
#  811   RH_4 -0.285927
#  812   RH_5 -0.263285
#  813   RH_6 -0.239540
#  814   RH_7 -0.213979
#  815   RH_8 -0.188644
#  816   RH_9 -0.168366
#  817  RH_10 -0.157451
#  818  RH_11 -0.161633
#  819  RH_12 -0.183960
#  820  RH_13 -0.225042
#  821  RH_14 -0.280881
#  822  RH_15 -0.344344
#  823  RH_16 -0.407398
#  824  RH_17 -0.462750
#  825  RH_18 -0.504740
#  826  RH_19 -0.528857
#  827  RH_20 -0.533604
#  828  RH_21 -0.518466
#  829  RH_22 -0.487669
#  830  RH_23 -0.446301
#  831  RH_24 -0.401877
#  832  RH_25 -0.362244
#  833  RH_26 -0.329041
#  834  RH_27 -0.300896
#  835  RH_28 -0.276577
#  836  RH_29 -0.253534
#  837  RH_30 -0.229607
#  ..     ...       ...
#  850  RH_43 -0.512088
#  851  RH_44 -0.512639
#  852  RH_45 -0.494934
#  853  RH_46 -0.463189
#  854  RH_47 -0.422019
#  855  RH_48 -0.378183
#  856  RH_49 -0.338429
#  857  RH_50 -0.304909
#  858  RH_51 -0.276103
#  859  RH_52 -0.250859
#  860  RH_53 -0.227332
#  861  RH_54 -0.203143
#  862  RH_55 -0.178783
#  863  RH_56 -0.156499
#  864  RH_57 -0.139599
#  865  RH_58 -0.133367
#  866  RH_59 -0.142175
#  867  RH_60 -0.169245
#  868  RH_61 -0.212972
#  869  RH_62 -0.269088
#  870  RH_63 -0.329938
#  871  RH_64 -0.388418
#  872  RH_65 -0.437439
#  873  RH_66 -0.471551
#  874  RH_67 -0.487508
#  875  RH_68 -0.484952
#  876  RH_69 -0.465000
#  877  RH_70 -0.431937
#  878  RH_71 -0.391454
#  879  RH_72 -0.348374
#
#  [72 rows x 2 columns], 12:       index      PM10
#  880   TMP_1  0.032874
#  881   TMP_2 -0.007718
#  882   TMP_3 -0.041558
#  883   TMP_4 -0.069599
#  884   TMP_5 -0.095141
#  885   TMP_6 -0.121938
#  886   TMP_7 -0.150968
#  887   TMP_8 -0.180131
#  888   TMP_9 -0.205087
#  889  TMP_10 -0.219604
#  890  TMP_11 -0.216222
#  891  TMP_12 -0.190162
#  892  TMP_13 -0.140071
#  893  TMP_14 -0.070741
#  894  TMP_15  0.007833
#  895  TMP_16  0.085615
#  896  TMP_17  0.152717
#  897  TMP_18  0.201766
#  898  TMP_19  0.227964
#  899  TMP_20  0.229860
#  900  TMP_21  0.208189
#  901  TMP_22  0.167421
#  902  TMP_23  0.113305
#  903  TMP_24  0.054041
#  904  TMP_25  0.004102
#  905  TMP_26 -0.037116
#  906  TMP_27 -0.070438
#  907  TMP_28 -0.098302
#  908  TMP_29 -0.123990
#  909  TMP_30 -0.150974
#  ..      ...       ...
#  922  TMP_43  0.204881
#  923  TMP_44  0.204085
#  924  TMP_45  0.181382
#  925  TMP_46  0.141113
#  926  TMP_47  0.089146
#  927  TMP_48  0.033226
#  928  TMP_49 -0.016215
#  929  TMP_50 -0.056900
#  930  TMP_51 -0.090859
#  931  TMP_52 -0.119779
#  932  TMP_53 -0.146406
#  933  TMP_54 -0.174003
#  934  TMP_55 -0.202470
#  935  TMP_56 -0.229013
#  936  TMP_57 -0.248924
#  937  TMP_58 -0.255903
#  938  TMP_59 -0.244395
#  939  TMP_60 -0.210493
#  940  TMP_61 -0.155224
#  941  TMP_62 -0.084776
#  942  TMP_63 -0.008219
#  943  TMP_64  0.064973
#  944  TMP_65  0.125616
#  945  TMP_66  0.166895
#  946  TMP_67  0.185740
#  947  TMP_68  0.181937
#  948  TMP_69  0.157292
#  949  TMP_70  0.116574
#  950  TMP_71  0.065645
#  951  TMP_72  0.011135
#
#  [72 rows x 2 columns], 13:        index      PM10
#  952    WSP_1 -0.125935
#  953    WSP_2 -0.190311
#  954    WSP_3 -0.237135
#  955    WSP_4 -0.272773
#  956    WSP_5 -0.300686
#  957    WSP_6 -0.320951
#  958    WSP_7 -0.332430
#  959    WSP_8 -0.329563
#  960    WSP_9 -0.310673
#  961   WSP_10 -0.272663
#  962   WSP_11 -0.214906
#  963   WSP_12 -0.144429
#  964   WSP_13 -0.071010
#  965   WSP_14 -0.007914
#  966   WSP_15  0.037183
#  967   WSP_16  0.065119
#  968   WSP_17  0.080034
#  969   WSP_18  0.086133
#  970   WSP_19  0.083166
#  971   WSP_20  0.071837
#  972   WSP_21  0.049835
#  973   WSP_22  0.020364
#  974   WSP_23 -0.015933
#  975   WSP_24 -0.055590
#  976   WSP_25 -0.099032
#  977   WSP_26 -0.141421
#  978   WSP_27 -0.179747
#  979   WSP_28 -0.212298
#  980   WSP_29 -0.238679
#  981   WSP_30 -0.257667
#  ...      ...       ...
#  994   WSP_43  0.129927
#  995   WSP_44  0.115397
#  996   WSP_45  0.092274
#  997   WSP_46  0.060726
#  998   WSP_47  0.023155
#  999   WSP_48 -0.016028
#  1000  WSP_49 -0.057275
#  1001  WSP_50 -0.097740
#  1002  WSP_51 -0.135798
#  1003  WSP_52 -0.169179
#  1004  WSP_53 -0.197105
#  1005  WSP_54 -0.217887
#  1006  WSP_55 -0.228301
#  1007  WSP_56 -0.224100
#  1008  WSP_57 -0.201600
#  1009  WSP_58 -0.160993
#  1010  WSP_59 -0.105675
#  1011  WSP_60 -0.040594
#  1012  WSP_61  0.023985
#  1013  WSP_62  0.077975
#  1014  WSP_63  0.116980
#  1015  WSP_64  0.140539
#  1016  WSP_65  0.150939
#  1017  WSP_66  0.151942
#  1018  WSP_67  0.144264
#  1019  WSP_68  0.127481
#  1020  WSP_69  0.102353
#  1021  WSP_70  0.070141
#  1022  WSP_71  0.033583
#  1023  WSP_72 -0.006678
#
#  [72 rows x 2 columns], 14:        index      PM10
#  1024   WDR_1 -0.196037
#  1025   WDR_2 -0.168074
#  1026   WDR_3 -0.147531
#  1027   WDR_4 -0.130351
#  1028   WDR_5 -0.110642
#  1029   WDR_6 -0.086933
#  1030   WDR_7 -0.059958
#  1031   WDR_8 -0.034928
#  1032   WDR_9 -0.016066
#  1033  WDR_10 -0.004783
#  1034  WDR_11  0.000335
#  1035  WDR_12  0.003904
#  1036  WDR_13  0.008271
#  1037  WDR_14  0.011026
#  1038  WDR_15  0.010342
#  1039  WDR_16 -0.000028
#  1040  WDR_17 -0.021395
#  1041  WDR_18 -0.052884
#  1042  WDR_19 -0.092746
#  1043  WDR_20 -0.136890
#  1044  WDR_21 -0.177761
#  1045  WDR_22 -0.206171
#  1046  WDR_23 -0.210094
#  1047  WDR_24 -0.190104
#  1048  WDR_25 -0.160718
#  1049  WDR_26 -0.133787
#  1050  WDR_27 -0.113317
#  1051  WDR_28 -0.093644
#  1052  WDR_29 -0.072642
#  1053  WDR_30 -0.048491
#  ...      ...       ...
#  1066  WDR_43 -0.068617
#  1067  WDR_44 -0.106225
#  1068  WDR_45 -0.138303
#  1069  WDR_46 -0.158956
#  1070  WDR_47 -0.161463
#  1071  WDR_48 -0.145072
#  1072  WDR_49 -0.122441
#  1073  WDR_50 -0.101643
#  1074  WDR_51 -0.082634
#  1075  WDR_52 -0.064249
#  1076  WDR_53 -0.045755
#  1077  WDR_54 -0.026302
#  1078  WDR_55 -0.004124
#  1079  WDR_56  0.018646
#  1080  WDR_57  0.033924
#  1081  WDR_58  0.044037
#  1082  WDR_59  0.047690
#  1083  WDR_60  0.046705
#  1084  WDR_61  0.047546
#  1085  WDR_62  0.046778
#  1086  WDR_63  0.039801
#  1087  WDR_64  0.025876
#  1088  WDR_65  0.003061
#  1089  WDR_66 -0.026485
#  1090  WDR_67 -0.058697
#  1091  WDR_68 -0.094320
#  1092  WDR_69 -0.124180
#  1093  WDR_70 -0.142397
#  1094  WDR_71 -0.143073
#  1095  WDR_72 -0.127983
#
#  [72 rows x 2 columns], 15:         index      PM10
#  1096   PM10_1  0.910002
#  1097   PM10_2  0.794762
#  1098   PM10_3  0.679225
#  1099   PM10_4  0.581328
#  1100   PM10_5  0.512566
#  1101   PM10_6  0.476044
#  1102   PM10_7  0.462718
#  1103   PM10_8  0.464103
#  1104   PM10_9  0.471365
#  1105  PM10_10  0.475370
#  1106  PM10_11  0.473107
#  1107  PM10_12  0.464461
#  1108  PM10_13  0.450917
#  1109  PM10_14  0.434247
#  1110  PM10_15  0.416028
#  1111  PM10_16  0.399260
#  1112  PM10_17  0.390244
#  1113  PM10_18  0.395429
#  1114  PM10_19  0.421229
#  1115  PM10_20  0.467498
#  1116  PM10_21  0.528649
#  1117  PM10_22  0.591469
#  1118  PM10_23  0.637575
#  1119  PM10_24  0.640811
#  1120  PM10_25  0.605154
#  1121  PM10_26  0.535210
#  1122  PM10_27  0.459934
#  1123  PM10_28  0.395109
#  1124  PM10_29  0.351489
#  1125  PM10_30  0.331390
#  ...       ...       ...
#  1138  PM10_43  0.327825
#  1139  PM10_44  0.369138
#  1140  PM10_45  0.419488
#  1141  PM10_46  0.469939
#  1142  PM10_47  0.504460
#  1143  PM10_48  0.507711
#  1144  PM10_49  0.478242
#  1145  PM10_50  0.424878
#  1146  PM10_51  0.366287
#  1147  PM10_52  0.316534
#  1148  PM10_53  0.283503
#  1149  PM10_54  0.269503
#  1150  PM10_55  0.270160
#  1151  PM10_56  0.278928
#  1152  PM10_57  0.290271
#  1153  PM10_58  0.298062
#  1154  PM10_59  0.300588
#  1155  PM10_60  0.297916
#  1156  PM10_61  0.292163
#  1157  PM10_62  0.284517
#  1158  PM10_63  0.274677
#  1159  PM10_64  0.265608
#  1160  PM10_65  0.263485
#  1161  PM10_66  0.273751
#  1162  PM10_67  0.299577
#  1163  PM10_68  0.339726
#  1164  PM10_69  0.386856
#  1165  PM10_70  0.432045
#  1166  PM10_71  0.463172
#  1167  PM10_72  0.466749
#
#  [72 rows x 2 columns]}

# %%
sixteen_equal_dfs_contiguous[key]
# Out:
#         index      PM10
# 1096   PM10_1  0.910002
# 1097   PM10_2  0.794762
# 1098   PM10_3  0.679225
# 1099   PM10_4  0.581328
# 1100   PM10_5  0.512566
# 1101   PM10_6  0.476044
# 1102   PM10_7  0.462718
# 1103   PM10_8  0.464103
# 1104   PM10_9  0.471365
# 1105  PM10_10  0.475370
# 1106  PM10_11  0.473107
# 1107  PM10_12  0.464461
# 1108  PM10_13  0.450917
# 1109  PM10_14  0.434247
# 1110  PM10_15  0.416028
# 1111  PM10_16  0.399260
# 1112  PM10_17  0.390244
# 1113  PM10_18  0.395429
# 1114  PM10_19  0.421229
# 1115  PM10_20  0.467498
# 1116  PM10_21  0.528649
# 1117  PM10_22  0.591469
# 1118  PM10_23  0.637575
# 1119  PM10_24  0.640811
# 1120  PM10_25  0.605154
# 1121  PM10_26  0.535210
# 1122  PM10_27  0.459934
# 1123  PM10_28  0.395109
# 1124  PM10_29  0.351489
# 1125  PM10_30  0.331390
# ...       ...       ...
# 1138  PM10_43  0.327825
# 1139  PM10_44  0.369138
# 1140  PM10_45  0.419488
# 1141  PM10_46  0.469939
# 1142  PM10_47  0.504460
# 1143  PM10_48  0.507711
# 1144  PM10_49  0.478242
# 1145  PM10_50  0.424878
# 1146  PM10_51  0.366287
# 1147  PM10_52  0.316534
# 1148  PM10_53  0.283503
# 1149  PM10_54  0.269503
# 1150  PM10_55  0.270160
# 1151  PM10_56  0.278928
# 1152  PM10_57  0.290271
# 1153  PM10_58  0.298062
# 1154  PM10_59  0.300588
# 1155  PM10_60  0.297916
# 1156  PM10_61  0.292163
# 1157  PM10_62  0.284517
# 1158  PM10_63  0.274677
# 1159  PM10_64  0.265608
# 1160  PM10_65  0.263485
# 1161  PM10_66  0.273751
# 1162  PM10_67  0.299577
# 1163  PM10_68  0.339726
# 1164  PM10_69  0.386856
# 1165  PM10_70  0.432045
# 1166  PM10_71  0.463172
# 1167  PM10_72  0.466749
#
# [72 rows x 2 columns]

# %%
list_of_dfs = {}
for df in ()

# %%
sixteen_equal_dfs_contiguous.items()
# Out:
# dict_items([(0,      index      PM10
# 16   UVA_1  0.080428
# 17   UVA_2  0.059288
# 18   UVA_3  0.054166
# 19   UVA_4  0.055623
# 20   UVA_5  0.052160
# 21   UVA_6  0.034876
# 22   UVA_7 -0.000719
# 23   UVA_8 -0.052856
# 24   UVA_9 -0.115930
# 25  UVA_10 -0.180952
# 26  UVA_11 -0.237134
# 27  UVA_12 -0.275227
# 28  UVA_13 -0.286804
# 29  UVA_14 -0.265479
# 30  UVA_15 -0.209555
# 31  UVA_16 -0.123668
# 32  UVA_17 -0.018581
# 33  UVA_18  0.088786
# 34  UVA_19  0.179283
# 35  UVA_20  0.236901
# 36  UVA_21  0.254140
# 37  UVA_22  0.233910
# 38  UVA_23  0.187841
# 39  UVA_24  0.134139
# 40  UVA_25  0.091404
# 41  UVA_26  0.068179
# 42  UVA_27  0.060532
# 43  UVA_28  0.058931
# 44  UVA_29  0.052635
# 45  UVA_30  0.032191
# ..     ...       ...
# 58  UVA_43  0.180298
# 59  UVA_44  0.232567
# 60  UVA_45  0.246284
# 61  UVA_46  0.225244
# 62  UVA_47  0.181013
# 63  UVA_48  0.130924
# 64  UVA_49  0.091275
# 65  UVA_50  0.068544
# 66  UVA_51  0.058896
# 67  UVA_52  0.053125
# 68  UVA_53  0.041963
# 69  UVA_54  0.018444
# 70  UVA_55 -0.021275
# 71  UVA_56 -0.074924
# 72  UVA_57 -0.136880
# 73  UVA_58 -0.197187
# 74  UVA_59 -0.245587
# 75  UVA_60 -0.273656
# 76  UVA_61 -0.274805
# 77  UVA_62 -0.245583
# 78  UVA_63 -0.185533
# 79  UVA_64 -0.100300
# 80  UVA_65 -0.000639
# 81  UVA_66  0.097219
# 82  UVA_67  0.175923
# 83  UVA_68  0.222737
# 84  UVA_69  0.233288
# 85  UVA_70  0.211744
# 86  UVA_71  0.169234
# 87  UVA_72  0.121485
#
# [72 rows x 2 columns]), (1,       index      PM10
# 88    UVB_1  0.045564
# 89    UVB_2  0.032666
# 90    UVB_3  0.040756
# 91    UVB_4  0.056312
# 92    UVB_5  0.063476
# 93    UVB_6  0.050496
# 94    UVB_7  0.013445
# 95    UVB_8 -0.042680
# 96    UVB_9 -0.108437
# 97   UVB_10 -0.172774
# 98   UVB_11 -0.226659
# 99   UVB_12 -0.264311
# 100  UVB_13 -0.279563
# 101  UVB_14 -0.264908
# 102  UVB_15 -0.214922
# 103  UVB_16 -0.129197
# 104  UVB_17 -0.017489
# 105  UVB_18  0.100359
# 106  UVB_19  0.198142
# 107  UVB_20  0.253269
# 108  UVB_21  0.257027
# 109  UVB_22  0.217989
# 110  UVB_23  0.157424
# 111  UVB_24  0.098477
# 112  UVB_25  0.058739
# 113  UVB_26  0.044469
# 114  UVB_27  0.050123
# 115  UVB_28  0.062260
# 116  UVB_29  0.065649
# 117  UVB_30  0.048724
# ..      ...       ...
# 130  UVB_43  0.199546
# 131  UVB_44  0.248245
# 132  UVB_45  0.248499
# 133  UVB_46  0.209568
# 134  UVB_47  0.151321
# 135  UVB_48  0.096524
# 136  UVB_49  0.060601
# 137  UVB_50  0.047577
# 138  UVB_51  0.051262
# 139  UVB_52  0.058507
# 140  UVB_53  0.056070
# 141  UVB_54  0.035683
# 142  UVB_55 -0.005487
# 143  UVB_56 -0.062549
# 144  UVB_57 -0.126517
# 145  UVB_58 -0.186175
# 146  UVB_59 -0.232490
# 147  UVB_60 -0.259986
# 148  UVB_61 -0.263518
# 149  UVB_62 -0.238843
# 150  UVB_63 -0.182387
# 151  UVB_64 -0.096837
# 152  UVB_65  0.007713
# 153  UVB_66  0.112329
# 154  UVB_67  0.194420
# 155  UVB_68  0.236559
# 156  UVB_69  0.233794
# 157  UVB_70  0.195556
# 158  UVB_71  0.140744
# 159  UVB_72  0.089743
#
# [72 rows x 2 columns]), (2,      index      PM10
# 160   PA_1  0.069874
# 161   PA_2  0.064093
# 162   PA_3  0.062272
# 163   PA_4  0.064430
# 164   PA_5  0.071135
# 165   PA_6  0.081955
# 166   PA_7  0.093743
# 167   PA_8  0.104045
# 168   PA_9  0.109691
# 169  PA_10  0.107756
# 170  PA_11  0.098245
# 171  PA_12  0.083121
# 172  PA_13  0.065141
# 173  PA_14  0.048057
# 174  PA_15  0.036125
# 175  PA_16  0.030600
# 176  PA_17  0.031542
# 177  PA_18  0.038674
# 178  PA_19  0.049502
# 179  PA_20  0.061871
# 180  PA_21  0.072375
# 181  PA_22  0.079004
# 182  PA_23  0.080765
# 183  PA_24  0.079215
# 184  PA_25  0.074786
# 185  PA_26  0.070997
# 186  PA_27  0.070494
# 187  PA_28  0.074297
# 188  PA_29  0.082111
# 189  PA_30  0.092614
# ..     ...       ...
# 202  PA_43  0.057241
# 203  PA_44  0.068654
# 204  PA_45  0.078874
# 205  PA_46  0.084823
# 206  PA_47  0.086199
# 207  PA_48  0.084714
# 208  PA_49  0.080692
# 209  PA_50  0.077232
# 210  PA_51  0.076645
# 211  PA_52  0.080319
# 212  PA_53  0.088018
# 213  PA_54  0.098430
# 214  PA_55  0.108403
# 215  PA_56  0.115616
# 216  PA_57  0.117496
# 217  PA_58  0.112426
# 218  PA_59  0.101748
# 219  PA_60  0.086721
# 220  PA_61  0.070414
# 221  PA_62  0.055437
# 222  PA_63  0.044336
# 223  PA_64  0.039313
# 224  PA_65  0.040786
# 225  PA_66  0.047430
# 226  PA_67  0.058421
# 227  PA_68  0.070101
# 228  PA_69  0.079049
# 229  PA_70  0.083908
# 230  PA_71  0.084281
# 231  PA_72  0.081801
#
# [72 rows x 2 columns]), (3,      index      PM10
# 232   CO_1  0.570232
# 233   CO_2  0.490675
# 234   CO_3  0.389232
# 235   CO_4  0.296713
# 236   CO_5  0.238036
# 237   CO_6  0.223180
# 238   CO_7  0.244199
# 239   CO_8  0.285868
# 240   CO_9  0.329730
# 241  CO_10  0.356326
# 242  CO_11  0.349886
# 243  CO_12  0.308710
# 244  CO_13  0.244283
# 245  CO_14  0.174688
# 246  CO_15  0.114463
# 247  CO_16  0.070698
# 248  CO_17  0.046794
# 249  CO_18  0.046869
# 250  CO_19  0.074664
# 251  CO_20  0.128484
# 252  CO_21  0.206491
# 253  CO_22  0.298163
# 254  CO_23  0.384282
# 255  CO_24  0.432031
# 256  CO_25  0.422797
# 257  CO_26  0.359527
# 258  CO_27  0.280260
# 259  CO_28  0.210060
# 260  CO_29  0.167857
# 261  CO_30  0.162129
# ..     ...       ...
# 274  CO_43  0.026158
# 275  CO_44  0.078426
# 276  CO_45  0.148506
# 277  CO_46  0.228398
# 278  CO_47  0.302059
# 279  CO_48  0.344368
# 280  CO_49  0.337152
# 281  CO_50  0.286995
# 282  CO_51  0.223091
# 283  CO_52  0.167717
# 284  CO_53  0.137188
# 285  CO_54  0.138356
# 286  CO_55  0.164573
# 287  CO_56  0.202217
# 288  CO_57  0.236505
# 289  CO_58  0.252047
# 290  CO_59  0.238375
# 418  NO2_43  0.167222
# 419  NO2_44  0.221384
# 420  NO2_45  0.280163
# 421  NO2_46  0.325316
# 422  NO2_47  0.340305
# 423  NO2_48  0.322228
# 424  NO2_49  0.285890
# 425  NO2_50  0.240431
# 426  NO2_51  0.203200
# 427  NO2_52  0.187026
# 428  NO2_53  0.194593
# 429  NO2_54  0.222824
# 430  NO2_55  0.262829
# 431  NO2_56  0.303111
# 432  NO2_57  0.331378
# 433  NO2_58  0.339779
# 434  NO2_59  0.327914
# 435  NO2_60  0.299299
# 436  NO2_61  0.256349
# 437  NO2_62  0.204748
# 438  NO2_63  0.155660
# 439  NO2_64  0.120022
# 440  NO2_65  0.105220
# 441  NO2_66  0.115503
# 442  NO2_67  0.150172
# 443  NO2_68  0.202327
# 444  NO2_69  0.256620
# 445  NO2_70  0.295128
# 446  NO2_71  0.306450
# 447  NO2_72  0.289647
#
# [72 rows x 2 columns]), (6,       index      PM10
# 448   NOX_1  0.551671
# 449   NOX_2  0.497568
# 450   NOX_3  0.411625
# 451   NOX_4  0.326660
# 452   NOX_5  0.269419
# 453   NOX_6  0.252750
# 454   NOX_7  0.270881
# 455   NOX_8  0.309491
# 456   NOX_9  0.351362
# 457  NOX_10  0.377320
# 458  NOX_11  0.371200
# 459  NOX_12  0.329475
# 460  NOX_13  0.261909
# 461  NOX_14  0.185850
# 462  NOX_15  0.116138
# 463  NOX_16  0.060765
# 464  NOX_17  0.023996
# 465  NOX_18  0.011465
# 466  NOX_19  0.027734
# 467  NOX_20  0.073760
# 468  NOX_21  0.149168
# 469  NOX_22  0.245054
# 470  NOX_23  0.343168
# 471  NOX_24  0.411503
# 472  NOX_25  0.425338
# 473  NOX_26  0.382486
# 474  NOX_27  0.315651
# 475  NOX_28  0.251300
# 476  NOX_29  0.210074
# 477  NOX_30  0.202108
# ..      ...       ...
# 490  NOX_43 -0.015048
# 491  NOX_44  0.030881
# 492  NOX_45  0.100288
# 493  NOX_46  0.185577
# 494  NOX_47  0.270501
# 495  NOX_48  0.330360
# 496  NOX_49  0.343133
# 497  NOX_50  0.310761
# 498  NOX_51  0.258421
# 499  NOX_52  0.208960
# 500  NOX_53  0.179915
# 501  NOX_54  0.179197
# 502  NOX_55  0.202253
# 503  NOX_56  0.236210
# 504  NOX_57  0.266846
# 505  NOX_58  0.279069
# 506  NOX_59  0.262224
# 507  NOX_60  0.217229
# 508  NOX_61  0.154459
# 509  NOX_62  0.088866
# 510  NOX_63  0.031298
# 511  NOX_64 -0.013255
# 512  NOX_65 -0.039181
# 513  NOX_66 -0.042017
# 514  NOX_67 -0.019681
# 515  NOX_68  0.028629
# 516  NOX_69  0.097038
# 517  NOX_70  0.176858
# 518  NOX_71  0.254562
# 519  NOX_72  0.308664
#
# [72 rows x 2 columns]), (7,      index      PM10
# 520   O3_1  0.139433
# 521   O3_2  0.129914
# 522   O3_3  0.123672
# 523   O3_4  0.110398
# 524   O3_5  0.083539
# 525   O3_6  0.041569
# 526   O3_7 -0.011116
# 527   O3_8 -0.067379
# 528   O3_9 -0.117345
# 650  PM2.5_59  0.141005
# 651  PM2.5_60  0.117321
# 652  PM2.5_61  0.099786
# 653  PM2.5_62  0.093673
# 654  PM2.5_63  0.098404
# 655  PM2.5_64  0.113988
# 656  PM2.5_65  0.139243
# 657  PM2.5_66  0.172631
# 658  PM2.5_67  0.211820
# 659  PM2.5_68  0.252775
# 660  PM2.5_69  0.287469
# 661  PM2.5_70  0.310753
# 662  PM2.5_71  0.317539
# 663  PM2.5_72  0.310633
#
# [72 rows x 2 columns]), (9,        index      PM10
# 664   PMCO_1  0.807673
# 665   PMCO_2  0.692203
# 666   PMCO_3  0.579211
# 667   PMCO_4  0.485107
# 668   PMCO_5  0.418883
# 669   PMCO_6  0.384872
# 670   PMCO_7  0.374274
# 671   PMCO_8  0.379968
# 672   PMCO_9  0.393039
# 673  PMCO_10  0.405289
# 674  PMCO_11  0.413416
# 675  PMCO_12  0.417495
# 676  PMCO_13  0.416951
# 677  PMCO_14  0.411855
# 678  PMCO_15  0.402442
# 679  PMCO_16  0.390569
# 680  PMCO_17  0.381987
# 681  PMCO_18  0.384651
# 682  PMCO_19  0.404812
# 683  PMCO_20  0.443568
# 684  PMCO_21  0.497326
# 685  PMCO_22  0.555024
# 686  PMCO_23  0.598177
# 687  PMCO_24  0.603459
# 688  PMCO_25  0.568776
# 689  PMCO_26  0.500318
# 690  PMCO_27  0.425203
# 691  PMCO_28  0.360274
# 692  PMCO_29  0.315713
# 693  PMCO_30  0.293976
# ..       ...       ...
# 706  PMCO_43  0.337115
# 707  PMCO_44  0.370332
# 708  PMCO_45  0.412688
# 709  PMCO_46  0.457220
# 710  PMCO_47  0.488406
# 711  PMCO_48  0.491773
# 712  PMCO_49  0.463369
# 713  PMCO_50  0.410109
# 714  PMCO_51  0.350876
# 715  PMCO_52  0.299496
# 716  PMCO_53  0.264492
# 717  PMCO_54  0.247652
# 718  PMCO_55  0.246034
# 719  PMCO_56  0.254471
# 720  PMCO_57  0.267864
# 721  PMCO_58  0.280005
# 722  PMCO_59  0.289123
# 723  PMCO_60  0.294643
# 724  PMCO_61  0.297583
# 725  PMCO_62  0.298054
# 726  PMCO_63  0.294185
# 727  PMCO_64  0.287998
# 728  PMCO_65  0.284001
# 729  PMCO_66  0.289825
# 730  PMCO_67  0.308729
# 731  PMCO_68  0.339980
# 732  PMCO_69  0.378441
# 733  PMCO_70  0.418366
# 734  PMCO_71  0.447648
# 735  PMCO_72  0.450905
#
# [72 rows x 2 columns]), (10,       index      PM10
# 736   SO2_1  0.313123
# 737   SO2_2  0.296921
# 738   SO2_3  0.283695
# 739   SO2_4  0.278228
# 740   SO2_5  0.281921
# 741   SO2_6  0.292559
# 742   SO2_7  0.303902
# 743   SO2_8  0.309302
# 744   SO2_9  0.304407
# 745  SO2_10  0.286177
# 746  SO2_11  0.262263
# 747  SO2_12  0.240907
# 748  SO2_13  0.222435
# 749  SO2_14  0.205650
# 750  SO2_15  0.189107
# 751  SO2_16  0.173046
# 752  SO2_17  0.160521
# 753  SO2_18  0.152742
# 754  SO2_19  0.152374
# 755  SO2_20  0.161440
# 756  SO2_21  0.180790
# 757  SO2_22  0.201454
# 758  SO2_23  0.217663
# 759  SO2_24  0.222175
# 760  SO2_25  0.220794
# 761  SO2_26  0.212650
# 762  SO2_27  0.206091
# 763  SO2_28  0.205090
# 764  SO2_29  0.211053
# 765  SO2_30  0.222047
# ..      ...       ...
# 778  SO2_43  0.109299
# 779  SO2_44  0.118373
# 780  SO2_45  0.135184
# 781  SO2_46  0.153590
# 782  SO2_47  0.166833
# 783  SO2_48  0.172709
# 784  SO2_49  0.171595
# 785  SO2_50  0.167701
# 786  SO2_51  0.164927
# 787  SO2_52  0.166522
# 788  SO2_53  0.170903
# 789  SO2_54  0.178652
# 790  SO2_55  0.185133
# 791  SO2_56  0.184955
# 792  SO2_57  0.176853
# 793  SO2_58  0.162603
# 794  SO2_59  0.145244
# 795  SO2_60  0.129225
# 796  SO2_61  0.114968
# 797  SO2_62  0.103056
# 798  SO2_63  0.093152
# 799  SO2_64  0.086587
# 800  SO2_65  0.083128
# 801  SO2_66  0.084488
# 802  SO2_67  0.093222
# 803  SO2_68  0.108282
# 804  SO2_69  0.127216
# 805  SO2_70  0.145431
# 806  SO2_71  0.158294
# 807  SO2_72  0.163692
#
# [72 rows x 2 columns]), (11,      index      PM10
# 808   RH_1 -0.366051
# 809   RH_2 -0.336802
# 810   RH_3 -0.309821
# 811   RH_4 -0.285927
# 812   RH_5 -0.263285
# 813   RH_6 -0.239540
# 814   RH_7 -0.213979
# 815   RH_8 -0.188644
# 816   RH_9 -0.168366
# 817  RH_10 -0.157451
# 818  RH_11 -0.161633
# 819  RH_12 -0.183960
# 820  RH_13 -0.225042
# 821  RH_14 -0.280881
# 822  RH_15 -0.344344
# 823  RH_16 -0.407398
# 824  RH_17 -0.462750
# 825  RH_18 -0.504740
# 826  RH_19 -0.528857
# 827  RH_20 -0.533604
# 828  RH_21 -0.518466
# 829  RH_22 -0.487669
# 830  RH_23 -0.446301
# 831  RH_24 -0.401877
# 832  RH_25 -0.362244
# 833  RH_26 -0.329041
# 834  RH_27 -0.300896
# 835  RH_28 -0.276577
# 836  RH_29 -0.253534
# 837  RH_30 -0.229607
# ..     ...       ...
# 850  RH_43 -0.512088
# 851  RH_44 -0.512639
# 852  RH_45 -0.494934
# 853  RH_46 -0.463189
# 854  RH_47 -0.422019
# 855  RH_48 -0.378183
# 856  RH_49 -0.338429
# 857  RH_50 -0.304909
# 858  RH_51 -0.276103
# 859  RH_52 -0.250859
# 860  RH_53 -0.227332
# 861  RH_54 -0.203143
# 862  RH_55 -0.178783
# 863  RH_56 -0.156499
# 864  RH_57 -0.139599
# 865  RH_58 -0.133367
# 866  RH_59 -0.142175
# 867  RH_60 -0.169245
# 868  RH_61 -0.212972
# 869  RH_62 -0.269088
# 870  RH_63 -0.329938
# 871  RH_64 -0.388418
# 872  RH_65 -0.437439
# 873  RH_66 -0.471551
# 874  RH_67 -0.487508
# 875  RH_68 -0.484952
# 876  RH_69 -0.465000
# 877  RH_70 -0.431937
# 878  RH_71 -0.391454
# 879  RH_72 -0.348374
#
# [72 rows x 2 columns]), (12,       index      PM10
# 880   TMP_1  0.032874
# 881   TMP_2 -0.007718
# 882   TMP_3 -0.041558
# 883   TMP_4 -0.069599
# 884   TMP_5 -0.095141
# 885   TMP_6 -0.121938
# 886   TMP_7 -0.150968
# 887   TMP_8 -0.180131
# 888   TMP_9 -0.205087
# 889  TMP_10 -0.219604
# 890  TMP_11 -0.216222
# 891  TMP_12 -0.190162
# 892  TMP_13 -0.140071
# 893  TMP_14 -0.070741
# 894  TMP_15  0.007833
# 895  TMP_16  0.085615
# 896  TMP_17  0.152717
# 897  TMP_18  0.201766
# 898  TMP_19  0.227964
# 899  TMP_20  0.229860
# 900  TMP_21  0.208189
# 901  TMP_22  0.167421
# 902  TMP_23  0.113305
# 903  TMP_24  0.054041
# 904  TMP_25  0.004102
# 905  TMP_26 -0.037116
# 906  TMP_27 -0.070438
# 907  TMP_28 -0.098302
# 908  TMP_29 -0.123990
# 909  TMP_30 -0.150974
# ..      ...       ...
# 922  TMP_43  0.204881
# 923  TMP_44  0.204085
# 924  TMP_45  0.181382
# 925  TMP_46  0.141113
# 926  TMP_47  0.089146
# 927  TMP_48  0.033226
# 928  TMP_49 -0.016215
# 929  TMP_50 -0.056900
# 930  TMP_51 -0.090859
# 931  TMP_52 -0.119779
# 932  TMP_53 -0.146406
# 933  TMP_54 -0.174003
# 934  TMP_55 -0.202470
# 935  TMP_56 -0.229013
# 936  TMP_57 -0.248924
# 937  TMP_58 -0.255903
# 938  TMP_59 -0.244395
# 939  TMP_60 -0.210493
# 940  TMP_61 -0.155224
# 941  TMP_62 -0.084776
# 942  TMP_63 -0.008219
# 943  TMP_64  0.064973
# 944  TMP_65  0.125616
# 945  TMP_66  0.166895
# 946  TMP_67  0.185740
# 947  TMP_68  0.181937
# 948  TMP_69  0.157292
# 949  TMP_70  0.116574
# 950  TMP_71  0.065645
# 951  TMP_72  0.011135
#
# [72 rows x 2 columns]), (13,        index      PM10
# 952    WSP_1 -0.125935
# 953    WSP_2 -0.190311
# 954    WSP_3 -0.237135
# 955    WSP_4 -0.272773
# 956    WSP_5 -0.300686
# 957    WSP_6 -0.320951
# 958    WSP_7 -0.332430
# 959    WSP_8 -0.329563
# 960    WSP_9 -0.310673
# 961   WSP_10 -0.272663
# 962   WSP_11 -0.214906
# 963   WSP_12 -0.144429
# 964   WSP_13 -0.071010
# 965   WSP_14 -0.007914
# 966   WSP_15  0.037183
# 967   WSP_16  0.065119
# 968   WSP_17  0.080034
# 969   WSP_18  0.086133
# 970   WSP_19  0.083166
# 971   WSP_20  0.071837
# 972   WSP_21  0.049835
# 973   WSP_22  0.020364
# 974   WSP_23 -0.015933
# 975   WSP_24 -0.055590
# 976   WSP_25 -0.099032
# 977   WSP_26 -0.141421
# 978   WSP_27 -0.179747
# 979   WSP_28 -0.212298
# 980   WSP_29 -0.238679
# 981   WSP_30 -0.257667
# ...      ...       ...
# 994   WSP_43  0.129927
# 995   WSP_44  0.115397
# 996   WSP_45  0.092274
# 997   WSP_46  0.060726
# 998   WSP_47  0.023155
# 999   WSP_48 -0.016028
# 1000  WSP_49 -0.057275
# 1001  WSP_50 -0.097740
# 1002  WSP_51 -0.135798
# 1003  WSP_52 -0.169179
# 1004  WSP_53 -0.197105
# 1005  WSP_54 -0.217887
# 1006  WSP_55 -0.228301
# 1007  WSP_56 -0.224100
# 1008  WSP_57 -0.201600
# 1009  WSP_58 -0.160993
# 1010  WSP_59 -0.105675
# 1011  WSP_60 -0.040594
# 1012  WSP_61  0.023985
# 1013  WSP_62  0.077975
# 1014  WSP_63  0.116980
# 1015  WSP_64  0.140539
# 1016  WSP_65  0.150939
# 1017  WSP_66  0.151942
# 1018  WSP_67  0.144264
# 1019  WSP_68  0.127481
# 1020  WSP_69  0.102353
# 1021  WSP_70  0.070141
# 1022  WSP_71  0.033583
# 1023  WSP_72 -0.006678
#
# [72 rows x 2 columns]), (14,        index      PM10
# 1024   WDR_1 -0.196037
# 1025   WDR_2 -0.168074
# 1026   WDR_3 -0.147531
# 1027   WDR_4 -0.130351
# 1028   WDR_5 -0.110642
# 1029   WDR_6 -0.086933
# 1030   WDR_7 -0.059958
# 1031   WDR_8 -0.034928
# 1032   WDR_9 -0.016066
# 1033  WDR_10 -0.004783
# 1034  WDR_11  0.000335
# 1035  WDR_12  0.003904
# 1036  WDR_13  0.008271
# 1037  WDR_14  0.011026
# 1038  WDR_15  0.010342
# 1039  WDR_16 -0.000028
# 1040  WDR_17 -0.021395
# 1041  WDR_18 -0.052884
# 1042  WDR_19 -0.092746
# 1043  WDR_20 -0.136890
# 1044  WDR_21 -0.177761
# 1045  WDR_22 -0.206171
# 1046  WDR_23 -0.210094
# 1047  WDR_24 -0.190104
# 1048  WDR_25 -0.160718
# 1049  WDR_26 -0.133787
# 1050  WDR_27 -0.113317
# 1051  WDR_28 -0.093644
# 1052  WDR_29 -0.072642
# 1053  WDR_30 -0.048491
# ...      ...       ...
# 1066  WDR_43 -0.068617
# 1067  WDR_44 -0.106225
# 1068  WDR_45 -0.138303
# 1069  WDR_46 -0.158956
# 1070  WDR_47 -0.161463
# 1071  WDR_48 -0.145072
# 1072  WDR_49 -0.122441
# 1073  WDR_50 -0.101643
# 1074  WDR_51 -0.082634
# 1075  WDR_52 -0.064249
# 1076  WDR_53 -0.045755
# 1077  WDR_54 -0.026302
# 1078  WDR_55 -0.004124
# 1079  WDR_56  0.018646
# 1080  WDR_57  0.033924
# 1081  WDR_58  0.044037
# 1082  WDR_59  0.047690
# 1083  WDR_60  0.046705
# 1084  WDR_61  0.047546
# 1085  WDR_62  0.046778
# 1086  WDR_63  0.039801
# 1087  WDR_64  0.025876
# 1088  WDR_65  0.003061
# 1089  WDR_66 -0.026485
# 1090  WDR_67 -0.058697
# 1091  WDR_68 -0.094320
# 1092  WDR_69 -0.124180
# 1093  WDR_70 -0.142397
# 1094  WDR_71 -0.143073
# 1095  WDR_72 -0.127983
#
# [72 rows x 2 columns]), (15,         index      PM10
# 1096   PM10_1  0.910002
# 1097   PM10_2  0.794762
# 1098   PM10_3  0.679225
# 1099   PM10_4  0.581328
# 1100   PM10_5  0.512566
# 1101   PM10_6  0.476044
# 1102   PM10_7  0.462718
# 1103   PM10_8  0.464103
# 1104   PM10_9  0.471365
# 1105  PM10_10  0.475370
# 1106  PM10_11  0.473107
# 1107  PM10_12  0.464461
# 1108  PM10_13  0.450917
# 1109  PM10_14  0.434247
# 1110  PM10_15  0.416028
# 1111  PM10_16  0.399260
# 1112  PM10_17  0.390244
# 1113  PM10_18  0.395429
# 1114  PM10_19  0.421229
# 1115  PM10_20  0.467498
# 1116  PM10_21  0.528649
# 1117  PM10_22  0.591469
# 1118  PM10_23  0.637575
# 1119  PM10_24  0.640811
# 1120  PM10_25  0.605154
# 1121  PM10_26  0.535210
# 1122  PM10_27  0.459934
# 1123  PM10_28  0.395109
# 1124  PM10_29  0.351489
# 1125  PM10_30  0.331390
# ...       ...       ...
# 1138  PM10_43  0.327825
# 1139  PM10_44  0.369138
# 1140  PM10_45  0.419488
# 1141  PM10_46  0.469939
# 1142  PM10_47  0.504460
# 1143  PM10_48  0.507711
# 1144  PM10_49  0.478242
# 1145  PM10_50  0.424878
# 1146  PM10_51  0.366287
# 1147  PM10_52  0.316534
# 1148  PM10_53  0.283503
# 1149  PM10_54  0.269503
# 1150  PM10_55  0.270160
# 1151  PM10_56  0.278928
# 1152  PM10_57  0.290271
# 1153  PM10_58  0.298062
# 1154  PM10_59  0.300588
# 1155  PM10_60  0.297916
# 1156  PM10_61  0.292163
# 1157  PM10_62  0.284517
# 1158  PM10_63  0.274677
# 1159  PM10_64  0.265608
# 1160  PM10_65  0.263485
# 1161  PM10_66  0.273751
# 1162  PM10_67  0.299577
# 1163  PM10_68  0.339726
# 1164  PM10_69  0.386856
# 1165  PM10_70  0.432045
# 1166  PM10_71  0.463172
# 1167  PM10_72  0.466749
#
# [72 rows x 2 columns])])

# %%
list_names = ['UVA', 'UVB', 'PA', 'CO', 'NO', 'NO2', 'NOX', 'O3', 'PM2.5', 'PMCO', 'SO2', 'RH'
             , 'TMP', 'WSP', 'WDR', 'PM10']

# %%
for name in list_names:
    for key in sixteen_equal_dfs_contiguous:
        #print(key)
        name = pd.DataFrame(data = sixteen_equal_dfs_contiguous.items())
        name

# %%
for (i in All.Files) {
a <- get(i)
   for (j in all.files) {
     b <- get(j)
     d <- dataframe(mergefun(a, b))
     newname <- paste("C", substr(j, 9, 12), sep="")
     names(d) <- c("Id", "Country", "logGDP", "GRI", "GRI.group", "Year")
     assign(newname,d)

   }  
}

# %%
def aislar(df):
    for i in range index:

# %% [markdown]
# ### PM10 y UVA

# %%
uva = PM10_72['indicador contaminante'] == "UVA"
PM10_UVA_72 = PM10_72[uva]

# %%
PM10_UVA_72.reset_index(inplace = True, drop = True)

# %%
del PM10_UVA_72['indicador contaminante']

# %%
PM10_UVA_72 = PM10_UVA_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_UVA_72['horas'] = PM10_UVA_72.index
PM10_UVA_72.head()

# %%
PM10_UVA_72 = PM10_UVA_72.rename(columns = {'PM10' : 'UVA'})
PM10_UVA_72.head()

# %%
PM10_UVA_72.drop(['Contaminante'], axis=1, inplace = True)
PM.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_uva = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_UVA_72, marker = 'o',  color='b', ax=ax)
#sns.scatterplot(x = 'horas', y = 'PM10', data = PM10_UVA_72, markers= True,  color='b', ax=ax)

pm10_uva.axes.set_title("Correlacion entre PM10 y UVA",fontsize=20)
pm10_uva.set_xlabel("Horas",fontsize=15)
pm10_uva.set_ylabel("Correlación",fontsize=15)
pm10_uva.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y UVB

# %%
PM10_UVB_72 = PM10_72[PM10_72['indicador contaminante'].isin(['UVB'])]

# %%
PM10_UVB_72.reset_index(inplace = True, drop = True)

# %%
del PM10_UVB_72['indicador contaminante']

# %%
PM10_UVB_72 = PM10_UVB_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_UVB_72['horas'] = PM10_UVB_72.index
PM10_UVB_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_uvb = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_UVB_72, marker = 'o',  color='r', ax=ax)

pm10_uvb.axes.set_title("Correlacion entre PM10 y UVB",fontsize=20)
pm10_uvb.set_xlabel("Horas",fontsize=15)
pm10_uvb.set_ylabel("Correlación",fontsize=15)
pm10_uvb.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y PA

# %%
PM10_PA_72 = PM10_72[PM10_72['indicador contaminante'].isin(['PA', 'PA_'])]

# %%
PM10_PA_72.reset_index(inplace = True, drop = True)

# %%
del PM10_PA_72['indicador contaminante']

# %%
PM10_PA_72 = PM10_PA_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_PA_72['horas'] = PM10_PA_72.index
PM10_PA_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_pa = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_PA_72, marker = 'o',  color='g', ax=ax)

pm10_pa.axes.set_title("Correlacion entre PM10 y PA",fontsize=20)
pm10_pa.set_xlabel("Horas",fontsize=15)
pm10_pa.set_ylabel("Correlación",fontsize=15)
pm10_pa.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y CO

# %%
PM10_CO_72 = PM10_72[PM10_72['indicador contaminante'].isin(['CO', 'CO_'])]

# %%
PM10_CO_72.reset_index(inplace = True, drop = True)

# %%
del PM10_CO_72['indicador contaminante']

# %%
PM10_CO_72 = PM10_CO_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_CO_72['horas'] = PM10_CO_72.index
PM10_CO_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_co = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_CO_72, marker = 'o',  color='c', ax=ax)

pm10_co.axes.set_title("Correlacion entre PM10 y CO",fontsize=20)
pm10_co.set_xlabel("Horas",fontsize=15)
pm10_co.set_ylabel("Correlación",fontsize=15)
pm10_co.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y NO

# %%
PM10_NO_72 = PM10_72[PM10_72['indicador contaminante'].isin(['NO', 'NO_'])]

# %%
PM10_NO_72.reset_index(inplace = True, drop = True)

# %%
del PM10_NO_72['indicador contaminante']

# %%
PM10_NO_72 = PM10_NO_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_NO_72['horas'] = PM10_NO_72.index
PM10_NO_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_no = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_NO_72, marker = 'o',  color='m', ax=ax)

pm10_no.axes.set_title("Correlacion entre PM10 y NO",fontsize=20)
pm10_no.set_xlabel("Horas",fontsize=15)
pm10_no.set_ylabel("Correlación",fontsize=15)
pm10_no.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y NO2

# %%
PM10_NO2_72 = PM10_72[PM10_72['indicador contaminante'].isin(['NO2'])]

# %%
PM10_NO2_72.reset_index(inplace = True, drop = True)

# %%
del PM10_NO2_72['indicador contaminante']

# %%
PM10_NO2_72 = PM10_NO2_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_NO2_72['horas'] = PM10_NO2_72.index
PM10_NO2_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_no2 = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_NO2_72, marker = 'o',  color='y', ax=ax)

pm10_no2.axes.set_title("Correlacion entre PM10 y NO2",fontsize=20)
pm10_no2.set_xlabel("Horas",fontsize=15)
pm10_no2.set_ylabel("Correlación",fontsize=15)
pm10_no2.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y NOX

# %%
PM10_NOX_72 = PM10_72[PM10_72['indicador contaminante'].isin(['NOX'])]

# %%
PM10_NOX_72.reset_index(inplace = True, drop = True)

# %%
del PM10_NOX_72['indicador contaminante']

# %%
PM10_NOX_72 = PM10_NOX_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_NOX_72['horas'] = PM10_NOX_72.index
PM10_NOX_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_nox = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_NOX_72, marker = 'o',  color='k', ax=ax)

pm10_nox.axes.set_title("Correlacion entre PM10 y NOX",fontsize=20)
pm10_nox.set_xlabel("Horas",fontsize=15)
pm10_nox.set_ylabel("Correlación",fontsize=15)
pm10_nox.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y 03

# %%
PM10_O3_72 = PM10_72[PM10_72['indicador contaminante'].isin(['O3', 'O3_'])]

# %%
PM10_O3_72.reset_index(inplace = True, drop = True)

# %%
del PM10_O3_72['indicador contaminante']

# %%
PM10_O3_72 = PM10_O3_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_O3_72['horas'] = PM10_O3_72.index
PM10_O3_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_o3 = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_O3_72, marker = 'o',  color='#800080', ax=ax)

pm10_o3.axes.set_title("Correlacion entre PM10 y O3",fontsize=20)
pm10_o3.set_xlabel("Horas",fontsize=15)
pm10_o3.set_ylabel("Correlación",fontsize=15)
pm10_o3.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y PM2.5

# %%
PM10_PM25_72 = PM10_72[PM10_72['indicador contaminante'].isin(['PM2', 'PM2.5'])]

# %%
PM10_PM25_72.reset_index(inplace = True, drop = True)

# %%
del PM10_PM25_72['indicador contaminante']

# %%
PM10_PM25_72 = PM10_PM25_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_PM25_72['horas'] = PM10_PM25_72.index
PM10_PM25_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_pm25 = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_PM25_72, marker = 'o',  color='#ff33ff', ax=ax)

pm10_pm25.axes.set_title("Correlacion entre PM10 y PM2.5",fontsize=20)
pm10_pm25.set_xlabel("Horas",fontsize=15)
pm10_pm25.set_ylabel("Correlación",fontsize=15)
pm10_pm25.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 Y PMCO

# %%
PM10_PMCO_72 = PM10_72[PM10_72['indicador contaminante'].isin(['PMC'])]

# %%
PM10_PMCO_72.reset_index(inplace = True, drop = True)

# %%
del PM10_PMCO_72['indicador contaminante']

# %%
PM10_PMCO_72 = PM10_PMCO_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_PMCO_72['horas'] = PM10_PMCO_72.index
PM10_PMCO_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_pmco = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_PMCO_72, marker = 'o',  color='#004d00', ax=ax)

pm10_pmco.axes.set_title("Correlacion entre PM10 y PMCO",fontsize=20)
pm10_pmco.set_xlabel("Horas",fontsize=15)
pm10_pmco.set_ylabel("Correlación",fontsize=15)
pm10_pmco.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 Y SO2

# %%
PM10_SO2_72 = PM10_72[PM10_72['indicador contaminante'].isin(['SO2'])]

# %%
PM10_SO2_72.reset_index(inplace = True, drop = True)

# %%
del PM10_SO2_72['indicador contaminante']

# %%
PM10_SO2_72 = PM10_SO2_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_SO2_72['horas'] = PM10_SO2_72.index
PM10_SO2_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_so2 = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_SO2_72, marker = 'o',  color='#ff751a', ax=ax)

pm10_so2.axes.set_title("Correlacion entre PM10 y SO2",fontsize=20)
pm10_so2.set_xlabel("Horas",fontsize=15)
pm10_so2.set_ylabel("Correlación",fontsize=15)
pm10_so2.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y RH

# %%
PM10_RH_72 = PM10_72[PM10_72['indicador contaminante'].isin(['RH', 'RH_'])]

# %%
PM10_RH_72.reset_index(inplace = True, drop = True)

# %%
del PM10_RH_72['indicador contaminante']

# %%
PM10_RH_72 = PM10_RH_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_RH_72['horas'] = PM10_RH_72.index
PM10_RH_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_rh = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_RH_72, marker = 'o',  color='#803300', ax=ax)

pm10_rh.axes.set_title("Correlacion entre PM10 y RH",fontsize=20)
pm10_rh.set_xlabel("Horas",fontsize=15)
pm10_rh.set_ylabel("Correlación",fontsize=15)
pm10_rh.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y TMP

# %%
PM10_TMP_72 = PM10_72[PM10_72['indicador contaminante'].isin(['TMP'])]

# %%
PM10_TMP_72.reset_index(inplace = True, drop = True)

# %%
del PM10_TMP_72['indicador contaminante']

# %%
PM10_TMP_72 = PM10_TMP_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_TMP_72['horas'] = PM10_TMP_72.index
PM10_TMP_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_tmp = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_TMP_72, marker = 'o',  color='#999900', ax=ax)

pm10_tmp.axes.set_title("Correlacion entre PM10 y TMP",fontsize=20)
pm10_tmp.set_xlabel("Horas",fontsize=15)
pm10_tmp.set_ylabel("Correlación",fontsize=15)
pm10_tmp.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 Y WSP

# %%
PM10_WSP_72 = PM10_72[PM10_72['indicador contaminante'].isin(['WSP'])]

# %%
PM10_WSP_72.reset_index(inplace = True, drop = True)

# %%
del PM10_WSP_72['indicador contaminante']

# %%
PM10_WSP_72 = PM10_WSP_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_WSP_72['horas'] = PM10_WSP_72.index
PM10_WSP_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_wsp = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_WSP_72, marker = 'o',  color='#ff3377', ax=ax)

pm10_wsp.axes.set_title("Correlacion entre PM10 y WSP",fontsize=20)
pm10_wsp.set_xlabel("Horas",fontsize=15)
pm10_wsp.set_ylabel("Correlación",fontsize=15)
pm10_wsp.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 y WDR

# %%
PM10_WDR_72 = PM10_72[PM10_72['indicador contaminante'].isin(['WDR'])]

# %%
PM10_WDR_72.reset_index(inplace = True, drop = True)

# %%
del PM10_WDR_72['indicador contaminante']

# %%
PM10_WDR_72 = PM10_WDR_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_WDR_72['horas'] = PM10_WDR_72.index
PM10_WDR_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10_wdr = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_WDR_72, marker = 'o',  color='#00b3b3', ax=ax)

pm10_wdr.axes.set_title("Correlacion entre PM10 y WDR",fontsize=20)
pm10_wdr.set_xlabel("Horas",fontsize=15)
pm10_wdr.set_ylabel("Correlación",fontsize=15)
pm10_wdr.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ### PM10 Y PM10

# %%
PM10_PM10_72 = PM10_72[PM10_72['indicador contaminante'].isin(['PM1', 'PM10'])]

# %%
PM10_PM10_72.reset_index(inplace = True, drop = True)

# %%
del PM10_PM10_72['indicador contaminante']

# %%
PM10_PM10_72 = PM10_PM10_72.rename(columns = {'index' : 'Contaminante'})

# %%
PM10_PM10_72['horas'] = PM10_PM10_72.index
PM10_PM10_72.head()

# %%
fig, ax = plt.subplots(figsize=(14,9))
pm10 = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_PM10_72, marker = 'o',  color='#4d2600', ax=ax)

pm10.axes.set_title("Autocorrelacion de PM10",fontsize=20)
pm10.set_xlabel("Horas",fontsize=15)
pm10.set_ylabel("Correlación",fontsize=15)
pm10.tick_params(labelsize=10)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,15))

pm10 = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_PM10_72, marker = 'o',  color='#4d2600', ax=ax)
pm10_wdr = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_WDR_72, marker = 'o',  color='#00b3b3', ax=ax)
pm10_wsp = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_WSP_72, marker = 'o',  color='#ff3377', ax=ax)
pm10_tmp = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_TMP_72, marker = 'o',  color='#999900', ax=ax)
pm10_rh = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_RH_72, marker = 'o',  color='#803300', ax=ax)
pm10_so2 = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_SO2_72, marker = 'o',  color='#ff751a', ax=ax)
pm10_pmco = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_PMCO_72, marker = 'o',  color='#004d00', ax=ax)
pm10_pm25 = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_PM25_72, marker = 'o',  color='#ff33ff', ax=ax)
pm10_o3 = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_O3_72, marker = 'o',  color='#800080', ax=ax)
pm10_nox = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_NOX_72, marker = 'o',  color='k', ax=ax)
pm10_no2 = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_NO2_72, marker = 'o',  color='y', ax=ax)
pm10_no = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_NO_72, marker = 'o',  color='m', ax=ax)
pm10_co = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_CO_72, marker = 'o',  color='c', ax=ax)
pm10_pa = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_PA_72, marker = 'o',  color='g', ax=ax)
pm10_uvb = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_UVB_72, marker = 'o',  color='r', ax=ax)
pm10_uva = sns.lineplot(x = 'horas', y = 'PM10', data = PM10_UVA_72, marker = 'o',  color='b', ax=ax)

# ax.set_xticklabels(PM10_UVB_72['horas'])
ax.legend(['PM10', 'WDR', 'WSP', 'TMP', 'RH', 'SO2', 'PMCO', 'PM25', 'O3', 'NOX',
           'NO2', 'NO', 'CO', 'PA', 'UVB', 'UVA'], facecolor='w')
plt.show()
