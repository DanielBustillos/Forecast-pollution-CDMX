# %% [markdown]
# ## ejemplos de manjeo de datos
#
# - tip 1
# - tip 2

# %%
import pandas as pd
import seaborn as sns
import pandas_profiling as pp
df = pd.read_csv("./cont_hora2000.csv")

# %%
df.tail()
# Out:
#         Unnamed: 0  RH  TMP  WDR  WSP id_station       fecha   CO   NO2   NOX  \
# 246448      246448 NaN  NaN  NaN  NaN        SUR  2001-01-01  2.1  27.0  37.0
# 246449      246449 NaN  NaN  NaN  NaN        TAX  2001-01-01  2.4  24.0  46.0
# 246450      246450 NaN  NaN  NaN  NaN        TLI  2001-01-01  3.1  16.0  41.0
# 246451      246451 NaN  NaN  NaN  NaN        UIZ  2001-01-01  3.0  19.0  44.0
# 246452      246452 NaN  NaN  NaN  NaN        VAL  2001-01-01  6.3   NaN   NaN
#
#          O3  PM10   SO2  hora  dia  mes
# 246448  5.0  83.0   6.0     0    1    1
# 246449  2.0  79.0  16.0     0    1    1
# 246450  NaN  24.0   6.0     0    1    1
# 246451  4.0   NaN  13.0     0    1    1
# 246452  NaN   NaN  29.0     0    1    1

# %%
sns.distplot(df["TMP"].dropna())

# %%
sns.violinplot(x="hora", y="O3",
               data=df)
sns.despine(left=True)

# %%
pp.ProfileReport(df.sample(500))
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
