# %% [markdown]
# # Datos entreneamiento Shift O3

# %% [markdown]
# En este notebook vamos a aplicar el shift para las obtener las columnas mas correlacionadas.
#
# - __Datos recibidos:__ obtenidos de notebook __1-datos_entrenamiento_shift.ipynb__
# - __Responsable:__ Daniel Bustillos
# - __Contacto:__  juandaniel.bucam@gmail.com
#
# __Notas del proyecto__
# Necesitamos generar un csv con los niveles máximos, mínimo y promedio por día, se perderá la información de la estación, también generaremos el atributo PM10mean y PM25mean que representarán los valores de las últimas 24 horas de los contaminantes.
#
# calidad de caire
# pronostico contaminación

# %% [markdown]
# ## Pasos
# [X] Aplicar Shift con Correlaciones <br>
# [X] Sacar minimo promedio y maximo <br>
# [X] Obtener columnas más correlacionadas<br><br>

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
path_inicial = "./datos/ingesta_hora_limpios.csv"
path_final = "./datos/ingesta_modelos_O3.csv"

# %%
data_hour_merge_24 = pd.read_csv(path_inicial)

# %%
data_hour_merge_24.head()
# Out:
#     CO   NO  NO2  NOX    O3  PM10  PM2.5    RH  SO2   TMP    WDR  WSP  dia  \
# 0  NaN  NaN  NaN  NaN   NaN   NaN    NaN  70.0  NaN  16.0   37.0  1.3    1
# 1  0.1  2.0  7.0  8.0  22.0  19.0   10.0  71.0  1.0  15.0  265.0  1.9    1
# 2  NaN  NaN  NaN  NaN  23.0   NaN    5.0   NaN  NaN   8.0  196.0  1.1    1
# 3  NaN  NaN  NaN  NaN   NaN   NaN    NaN   NaN  NaN   NaN    NaN  NaN    1
# 4  NaN  NaN  NaN  NaN   NaN   NaN    NaN   NaN  NaN   NaN    NaN  NaN    1
#
#                  fecha  hora id_station  mes  PM10mean  PM25mean
# 0  2019-08-01 01:00:00     1        ACO    8       NaN       NaN
# 1  2019-08-01 01:00:00     1        AJM    8       NaN       NaN
# 2  2019-08-01 01:00:00     1        AJU    8       NaN       NaN
# 3  2019-08-01 01:00:00     1        ARA    8       NaN       NaN
# 4  2019-08-01 01:00:00     1        ATI    8       NaN       NaN

# %% [markdown]
# #Quedémonos sin WSR:

# %%
data_hour_merge_24 = data_hour_merge_24[['CO', 'NO', 'NO2', 'NOX', 'O3', 'PM10', "PM2.5",'RH', 'SO2', 'TMP',
       'WSP', 'dia', 'fecha', 'hora', 'id_station', 'mes',"PM10mean","PM25mean"]].reset_index(drop=True)

# %% [markdown]
# #Hagamos una lista con todas las estaciones:

# %% [markdown]
# ### Arreglemos las fechas:

# %%
data_hour_merge_24['dia'] = data_hour_merge_24['dia'].astype(str).astype(float)
data_hour_merge_24['mes'] = data_hour_merge_24['mes'].astype(str).astype(float)

# %% [markdown]
# #Creemos un diccionario con __data_hour_merge_24__ dividido por #estación:

# %%
estaciones = data_hour_merge_24.id_station.unique().tolist()

# %%
data_est = {}
for elem in estaciones:
    data_est[elem] = data_hour_merge_24[data_hour_merge_24.id_station == elem]

# %% [markdown]
# # Leamos el archivo de correlaciones del PM10 mean

# %% [markdown]
# Este archivo se generó en el notebook: __/home/paw/DanielBustillos/contaminación/correlaciones_pau/correlaciones_función_paulina.ipynb__

# %%
target = "O3_y"

O3_corr = pd.read_csv("/DATA/paw/jupyterhub_notebook/daniel.bustillos/DanielBustillos/contaminación/pipeline-norberto/correlacion"+   
                      "/correlaciones_"+ target +".csv")
O3_corr = O3_corr.iloc[:,1:]

# %%
O3_corr.valor.min()
# Out:
# -0.6889562885482784

# %% [markdown]
# Vamos a quedarnos con las variables con corr>0.36:

# %%
O3_corr_filtro = O3_corr

# %%
 O3_corr_filtro = O3_corr[(O3_corr.valor>0.44) | (O3_corr.valor<-.44) ].reset_index(drop=True)

# %% [markdown]
# Vamos a aplicar el shift para cada elemento de la tabla __O3_corr__:

# %%
def shit_corr(df):
    for i in range(len(O3_corr_filtro)):
        name_column = str( O3_corr_filtro.loc[i,"contaminante"] + "_" + str( O3_corr_filtro.loc[i,"horas"] ) ) 
        df[name_column] = df[O3_corr_filtro.loc[i,"contaminante"]].shift(  int(float(str(O3_corr_filtro.loc[i,"horas"]))) ) 
    return df.dropna()

# %% [markdown]
# Aplicamos esta función para cada DF de cada estación:

# %%
data_shift = {}
for elem in data_est:
    data_shift[elem] = shit_corr(data_est[elem])

# %%
df_append = pd.DataFrame(columns = data_est["MER"].columns.tolist())

# %%
for key in data_est:
    df_append = df_append.append(data_est[key], ignore_index=True,sort=True)

# %% [markdown]
# ## Groupbys

# %%
cols = df_append.columns.tolist()

# %%
#cols.remove("id_station")
cols.remove("fecha")

# %% [markdown]
# Finalmente, aplicamos los groupbys:

# %% [raw]
# #data_hour_merge_24_mean = df_append.groupby(['fecha']).mean()
# #data_hour_merge_24_mean.reset_index(inplace=True)

# %% [raw]
# #data_hour_merge_24_max = df_append.groupby(['fecha']).max()
# #data_hour_merge_24_max.reset_index(inplace=True)

# %% [raw]
# #data_hour_merge_24_min = df_append.groupby(['fecha']).min()
# #data_hour_merge_24_min.reset_index(inplace=True)

# %%
data_hour_merge_24_mean = df_append.groupby('fecha')[cols].mean()
data_hour_merge_24_mean.reset_index(inplace=True)

# %%
data_hour_merge_24_max = df_append.groupby('fecha')[cols].max()
data_hour_merge_24_max.reset_index(inplace=True)

# %%
data_hour_merge_24_min = df_append.groupby('fecha')[cols].min()
data_hour_merge_24_min.reset_index(inplace=True)

# %% [markdown]
# ### Arreglemos los nombres:

# %%
max_columns = data_hour_merge_24_max.columns.tolist()
min_columns = data_hour_merge_24_min.columns.tolist()
mean_columns = data_hour_merge_24_mean.columns.tolist()

# %%
for i in range(len(max_columns)):
    if max_columns[i] not in ['fecha','hora','dia','mes','id_station']:
        max_columns[i] = max_columns[i]+"_max"
        min_columns[i] = min_columns[i]+"_min"    
        mean_columns[i] = mean_columns[i]+"_mean"

# %%
data_hour_merge_24_mean.columns = mean_columns
data_hour_merge_24_min.columns = min_columns
data_hour_merge_24_max.columns = max_columns

# %%
data_hour_merge_24_max.head()
# Out:
#                  fecha  CO_max  CO_6.0_max  CO_7.0_max  NO_max  NO2_max  \
# 0  2019-08-01 01:00:00    0.80         NaN         NaN     5.0     30.0
# 1  2019-08-01 02:00:00    0.56         NaN         NaN     6.0     36.0
# 2  2019-08-01 03:00:00    0.58         NaN         NaN    14.0     32.0
# 3  2019-08-01 04:00:00    0.56         NaN         NaN    26.0     31.0
# 4  2019-08-01 05:00:00    1.01         NaN         NaN    58.0     41.0
#
#    NOX_max  NOX_30.0_max  NOX_31.0_max  NOX_6.0_max  ...  hora_20.0_max  \
# 0     33.0           NaN           NaN          NaN  ...            NaN
# 1     41.0           NaN           NaN          NaN  ...            NaN
# 2     36.0           NaN           NaN          NaN  ...            NaN
# 3     41.0           NaN           NaN          NaN  ...            NaN
# 4     89.0           NaN           NaN          NaN  ...            NaN
#
#    hora_21.0_max  hora_33.0_max  hora_34.0_max  hora_35.0_max  hora_43.0_max  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    hora_44.0_max  hora_9.0_max  id_station  mes
# 0            NaN           NaN         XAL  8.0
# 1            NaN           NaN         XAL  8.0
# 2            NaN           NaN         XAL  8.0
# 3            NaN           NaN         XAL  8.0
# 4            NaN           NaN         XAL  8.0
#
# [5 rows x 99 columns]

# %% [markdown]
# ##### Unamos los df's de manera que tengamos en una solo los datos promedio, máximo y minimo por día:

# %%
data_hour_merge = pd.merge(data_hour_merge_24_mean, data_hour_merge_24_max, on=['fecha'])
data_hour_merge = pd.merge(data_hour_merge, data_hour_merge_24_min, on=['fecha'])
data_hour_merge = data_hour_merge.sort_values(['fecha',"hora_x"], ascending=[0,1])

# %%
data_hour_merge.head(48)
# Out:
#                    fecha   CO_mean  CO_6.0_mean  CO_7.0_mean    NO_mean  \
# 803  2019-09-03 14:00:00       NaN          NaN          NaN        NaN
# 802  2019-09-03 13:00:00       NaN          NaN          NaN        NaN
# 801  2019-09-03 12:00:00       NaN          NaN          NaN        NaN
# 800  2019-09-03 11:00:00       NaN          NaN          NaN        NaN
# 799  2019-09-03 10:00:00       NaN          NaN          NaN        NaN
# 798  2019-09-03 09:00:00       NaN          NaN          NaN        NaN
# 797  2019-09-03 08:00:00       NaN          NaN          NaN        NaN
# 796  2019-09-03 07:00:00       NaN          NaN          NaN        NaN
# 795  2019-09-03 06:00:00       NaN          NaN          NaN        NaN
# 794  2019-09-03 05:00:00       NaN          NaN          NaN        NaN
# 793  2019-09-03 04:00:00       NaN          NaN          NaN        NaN
# 792  2019-09-03 03:00:00       NaN          NaN          NaN        NaN
# 791  2019-09-03 02:00:00       NaN          NaN          NaN        NaN
# 790  2019-09-03 01:00:00       NaN          NaN          NaN        NaN
# 789  2019-09-03 00:00:00       NaN          NaN          NaN        NaN
# 788  2019-09-02 23:00:00       NaN          NaN          NaN        NaN
# 787  2019-09-02 22:00:00       NaN          NaN          NaN        NaN
# 786  2019-09-02 21:00:00       NaN          NaN          NaN        NaN
# 785  2019-09-02 20:00:00       NaN          NaN          NaN        NaN
# 784  2019-09-02 19:00:00       NaN          NaN          NaN        NaN
# 783  2019-09-02 18:00:00       NaN          NaN          NaN        NaN
# 782  2019-09-02 17:00:00       NaN          NaN          NaN        NaN
# 781  2019-09-02 16:00:00       NaN          NaN          NaN        NaN
# 780  2019-09-02 15:00:00       NaN          NaN          NaN        NaN
# 779  2019-09-02 12:00:00  0.530000     0.660588     0.378125   6.200000
# 778  2019-09-02 11:00:00  0.601875     0.378125     0.298750   9.176471
# 777  2019-09-02 10:00:00  0.627059     0.298750     0.279375  14.647059
# 776  2019-09-02 09:00:00  0.721176     0.279375     0.270000  21.058824
# 775  2019-09-02 08:00:00  1.062353     0.270000     0.263529  38.470588
# 774  2019-09-02 07:00:00  1.007059     0.263529     0.291765  43.823529
# 773  2019-09-02 06:00:00  0.660588     0.291765     0.350625  25.235294
# 772  2019-09-02 05:00:00  0.378125     0.350625     0.380000   6.687500
# 771  2019-09-02 04:00:00  0.298750     0.380000     0.406875   1.200000
# 770  2019-09-02 03:00:00  0.279375     0.406875     0.393125   0.733333
# 769  2019-09-02 02:00:00  0.270000     0.393125     0.356250   0.600000
# 768  2019-09-02 01:00:00  0.263529     0.356250     0.291765   0.812500
# 767  2019-09-02 00:00:00  0.291765     0.291765     0.273529   1.250000
# 766  2019-09-01 23:00:00  0.350625     0.273529     0.277059   1.066667
# 765  2019-09-01 22:00:00  0.380000     0.277059     0.344118   1.733333
# 764  2019-09-01 21:00:00  0.406875     0.344118     0.367647   1.866667
# 763  2019-09-01 20:00:00  0.393125     0.367647     0.404118   1.933333
# 762  2019-09-01 19:00:00  0.356250     0.404118     0.404375   1.875000
# 761  2019-09-01 18:00:00  0.291765     0.404375     0.472353   1.352941
# 760  2019-09-01 17:00:00  0.273529     0.472353     0.540000   1.235294
# 759  2019-09-01 16:00:00  0.277059     0.540000     0.647647   1.352941
# 758  2019-09-01 15:00:00  0.344118     0.647647     0.704118   1.176471
# 757  2019-09-01 14:00:00  0.367647     0.704118     0.657059   1.352941
# 756  2019-09-01 13:00:00  0.404118     0.657059     0.509412   1.941176
#
#       NO2_mean   NOX_mean  NOX_30.0_mean  NOX_31.0_mean  NOX_6.0_mean  ...  \
# 803        NaN        NaN            NaN            NaN           NaN  ...
# 802        NaN        NaN            NaN            NaN           NaN  ...
# 801        NaN        NaN            NaN            NaN           NaN  ...
# 800        NaN        NaN            NaN            NaN           NaN  ...
# 799        NaN        NaN            NaN            NaN           NaN  ...
# 798        NaN        NaN            NaN            NaN           NaN  ...
# 797        NaN        NaN            NaN            NaN           NaN  ...
# 796        NaN        NaN            NaN            NaN           NaN  ...
# 795        NaN        NaN            NaN            NaN           NaN  ...
# 794        NaN        NaN            NaN            NaN           NaN  ...
# 793        NaN        NaN            NaN            NaN           NaN  ...
# 792        NaN        NaN            NaN            NaN           NaN  ...
# 791        NaN        NaN            NaN            NaN           NaN  ...
# 790        NaN        NaN            NaN            NaN           NaN  ...
# 789        NaN        NaN            NaN            NaN           NaN  ...
# 788        NaN        NaN            NaN            NaN           NaN  ...
# 787        NaN        NaN            NaN            NaN           NaN  ...
# 786        NaN        NaN            NaN            NaN           NaN  ...
# 785        NaN        NaN            NaN            NaN           NaN  ...
# 784        NaN        NaN            NaN            NaN           NaN  ...
# 783        NaN        NaN            NaN            NaN           NaN  ...
# 782        NaN        NaN            NaN            NaN           NaN  ...
# 781        NaN        NaN            NaN            NaN           NaN  ...
# 780        NaN        NaN            NaN            NaN           NaN  ...
# 779  17.611111  24.266667      30.333333      17.166667     48.941176  ...
# 778  19.904762  29.235294      17.166667      14.944444     22.187500  ...
# 777  21.857143  36.882353      14.944444      13.833333     12.466667  ...
# 776  23.150000  44.764706      13.833333      13.055556     10.000000  ...
# 775  26.600000  65.058824      13.055556      14.117647      8.266667  ...
# 774  26.650000  70.176471      14.117647      15.062500      9.437500  ...
# 773  23.842105  48.941176      15.062500      15.937500     11.562500  ...
# 772  15.500000  22.187500      15.937500      16.066667     12.533333  ...
# 771  10.705882  12.466667      16.066667      15.375000     14.600000  ...
# 770   9.000000  10.000000      15.375000      14.600000     14.133333  ...
# 769   7.588235   8.266667      14.600000      12.470588     13.600000  ...
# 768   8.444444   9.437500      12.470588      11.312500     11.875000  ...
# 767  10.333333  11.562500      11.312500      10.823529      9.117647  ...
# 766  11.470588  12.533333      10.823529      11.235294      7.705882  ...
# 765  12.823529  14.600000      11.235294      11.764706      8.235294  ...
# 764  12.294118  14.133333      11.764706      15.058824      9.588235  ...
# 763  11.470588  13.600000      15.058824      18.470588     11.352941  ...
# 762   9.600000  11.875000      18.470588      22.375000     13.647059  ...
# 761   7.333333   9.117647      22.375000      28.058824     15.375000  ...
# 760   6.190476   7.705882      28.058824      40.470588     22.352941  ...
# 759   6.285714   8.235294      40.470588      52.187500     28.117647  ...
# 758   7.761905   9.588235      52.187500      77.333333     38.352941  ...
# 757   9.095238  11.352941      77.333333      80.388889     48.333333  ...
# 756  10.952381  13.647059      80.388889      59.833333     42.000000  ...
#
#      hora_20.0_min  hora_21.0_min  hora_33.0_min  hora_34.0_min  \
# 803            4.0            3.0           21.0           21.0
# 802            3.0            2.0           20.0           20.0
# 801            2.0            1.0           19.0           19.0
# 800            1.0            0.0           18.0           18.0
# 799            0.0            0.0           17.0           17.0
# 798           23.0           22.0           16.0           16.0
# 797           22.0           21.0           15.0           15.0
# 796           21.0           20.0           15.0            NaN
# 795           20.0           19.0            NaN            NaN
# 794           19.0           18.0            NaN            NaN
# 793           18.0           17.0            NaN            NaN
# 792           17.0           16.0            NaN            NaN
# 791           16.0           15.0            NaN            NaN
# 790           15.0           15.0            NaN            NaN
# 789            NaN            NaN            NaN            NaN
# 788            NaN            NaN            NaN            NaN
# 787            NaN            NaN            NaN            NaN
# 786            NaN            NaN            NaN            NaN
# 785            NaN            NaN            NaN            NaN
# 784            NaN            NaN            NaN            NaN
# 783            NaN            NaN            NaN            NaN
# 782            NaN            NaN            NaN            NaN
# 781            NaN            NaN            NaN            NaN
# 780            NaN            NaN            NaN            NaN
# 779           16.0           15.0            3.0            2.0
# 778           15.0           14.0            2.0            1.0
# 777           14.0           13.0            1.0            0.0
# 776           13.0           12.0            0.0           23.0
# 775           12.0           11.0           23.0           22.0
# 774           11.0           10.0           22.0           21.0
# 773           10.0            9.0           21.0           20.0
# 772            9.0            8.0           20.0           19.0
# 771            8.0            7.0           19.0           18.0
# 770            7.0            6.0           18.0           17.0
# 769            6.0            5.0           17.0           16.0
# 768            5.0            4.0           16.0           15.0
# 767            4.0            3.0           15.0           14.0
# 766            3.0            2.0           14.0           13.0
# 765            2.0            1.0           13.0           12.0
# 764            1.0            0.0           12.0           11.0
# 763            0.0           23.0           11.0           10.0
# 762           23.0           22.0           10.0            9.0
# 761           22.0           21.0            9.0            8.0
# 760           21.0           20.0            8.0            7.0
# 759           20.0           19.0            7.0            6.0
# 758           19.0           18.0            6.0            5.0
# 757           18.0           17.0            5.0            4.0
# 756           17.0           16.0            4.0            3.0
#
#      hora_35.0_min  hora_43.0_min  hora_44.0_min  hora_9.0_min  id_station_y  \
# 803           20.0           16.0           16.0           9.0        pronos
# 802           19.0           15.0           15.0           8.0        pronos
# 801           18.0           15.0            NaN           7.0        pronos
# 800           17.0            NaN            NaN           6.0        pronos
# 799           16.0            NaN            NaN           5.0        pronos
# 798           15.0            NaN            NaN           4.0        pronos
# 797           15.0            NaN            NaN           3.0        pronos
# 796            NaN            NaN            NaN           2.0        pronos
# 795            NaN            NaN            NaN           1.0        pronos
# 794            NaN            NaN            NaN           0.0        pronos
# 793            NaN            NaN            NaN           0.0        pronos
# 792            NaN            NaN            NaN          22.0        pronos
# 791            NaN            NaN            NaN          21.0        pronos
# 790            NaN            NaN            NaN          20.0        pronos
# 789            NaN            NaN            NaN          19.0        pronos
# 788            NaN            NaN            NaN          18.0        pronos
# 787            NaN            NaN            NaN          17.0        pronos
# 786            NaN            NaN            NaN          16.0        pronos
# 785            NaN            NaN            NaN          15.0        pronos
# 784            NaN            NaN            NaN          15.0        pronos
# 783            NaN            NaN            NaN           NaN        pronos
# 782            NaN            NaN            NaN           NaN        pronos
# 781            NaN            NaN            NaN           NaN        pronos
# 780            NaN            NaN            NaN           NaN        pronos
# 779            1.0           17.0           16.0           3.0           ACO
# 778            0.0           16.0           15.0           2.0           ACO
# 777           23.0           15.0           14.0           1.0           ACO
# 776           22.0           14.0           13.0           0.0           ACO
# 775           21.0           13.0           12.0          23.0           ACO
# 774           20.0           12.0           11.0          22.0           ACO
# 773           19.0           11.0           10.0          21.0           ACO
# 772           18.0           10.0            9.0          20.0           ACO
# 771           17.0            9.0            8.0          19.0           ACO
# 770           16.0            8.0            7.0          18.0           ACO
# 769           15.0            7.0            6.0          17.0           ACO
# 768           14.0            6.0            5.0          16.0           ACO
# 767           13.0            5.0            4.0          15.0           ACO
# 766           12.0            4.0            3.0          14.0           ACO
# 765           11.0            3.0            2.0          13.0           ACO
# 764           10.0            2.0            1.0          12.0           ACO
# 763            9.0            1.0            0.0          11.0           ACO
# 762            8.0            0.0           23.0          10.0           ACO
# 761            7.0           23.0           22.0           9.0           ACO
# 760            6.0           22.0           21.0           8.0           ACO
# 759            5.0           21.0           20.0           7.0           ACO
# 758            4.0           20.0           19.0           6.0           ACO
# 757            3.0           19.0           18.0           5.0           ACO
# 756            2.0           18.0           17.0           4.0           ACO
#
#      mes_y
# 803    9.0
# 802    9.0
# 801    9.0
# 800    9.0
# 799    9.0
# 798    9.0
# 797    9.0
# 796    9.0
# 795    9.0
# 794    9.0
# 793    9.0
# 792    9.0
# 791    9.0
# 790    9.0
# 789    9.0
# 788    9.0
# 787    9.0
# 786    9.0
# 785    9.0
# 784    9.0
# 783    9.0
# 782    9.0
# 781    9.0
# 780    9.0
# 779    9.0
# 778    9.0
# 777    9.0
# 776    9.0
# 775    9.0
# 774    9.0
# 773    9.0
# 772    9.0
# 771    9.0
# 770    9.0
# 769    9.0
# 768    9.0
# 767    9.0
# 766    9.0
# 765    9.0
# 764    9.0
# 763    9.0
# 762    9.0
# 761    9.0
# 760    9.0
# 759    9.0
# 758    9.0
# 757    9.0
# 756    9.0
#
# [48 rows x 293 columns]

# %% [markdown]
# ## Correlacionados con el target.

# %% [markdown]
# Ahora vamos a sacar los atributos más correlacionado con el target, el target es la columna a pronosticar, por simplicidad solo vamos a sacar la correlación con target a las 12 horas:

# %% [markdown]
# Generemos los target de pronóstico:

# %% [markdown]
# Filtremos el DF con las variables mas correlacionadas:

# %% [markdown]
# # agregar 'fecha'

# %%
O3_corr = ['O3_47.0_max',  'TMP_45.0_mean',  'O3_2.0_mean',  'RH_45.0_mean',  'RH_2.0_mean',  'RH_25.0_min',  'O3_23.0_mean',  'RH_44.0_min',  'RH_25.0_mean',  'RH_23.0_max',  'TMP_46.0_mean',  'O3_26.0_mean',  'RH_21.0_max',  'O3_23.0_min',  'TMP_mean',  'O3_22.0_max',  'RH_0.0_min',  'TMP_2.0_min',  'O3_21.0_mean',  'O3_45.0_min',  'hora_35.0_mean',  'NOX_8.0_mean',  'RH_3.0_max',  'hora_20.0_mean',  'TMP_47.0_mean',  'RH_44.0_mean',  'O3_1.0_max',  'NO_7.0_mean',  'RH_46.0_max',  'RH_46.0_mean',  'hora_19.0_mean',  'NO_8.0_max',  'O3_22.0_mean',  'hora_44.0_mean',  'TMP_22.0_max',  'hora_11.0_mean',  'O3_21.0_min',  'O3_25.0_max',  'RH_26.0_mean',  'O3_48.0_mean',  'TMP_21.0_max',  'O3_21.0_max',  'O3_46.0_max',  'TMP_21.0_mean',  'RH_45.0_min',  'RH_24.0_min',  'RH_22.0_mean',  'hora_10.0',  'RH_24.0_mean',  'NOX_7.0_max',  'NOX_7.0_mean',  'O3_25.0_mean',  'TMP_47.0_max',  'TMP_1.0_mean',  'hora_10.0_min',  'O3_3.0_max',  'O3_0.0_mean',  'RH_22.0_max',  'O3_45.0_mean',  'RH_22.0_min',  'RH_48.0_max',  'TMP_25.0_max',  'O3_0.0_min',  'RH_26.0_max',  'hora_34.0_mean',  'RH_min',  'TMP_0.0_max',  'O3_0.0_max',  'O3_46.0_min',  'TMP_22.0_mean',  'O3_45.0_max',  'RH_23.0_min',  'hora_10.0_max',  'O3_24.0_min',  'hora_11.0_min',  'RH_mean',  'TMP_24.0_mean',  'O3_min',  'TMP_48.0_mean',  'O3_46.0_mean',  'TMP_2.0_mean',  'TMP_max',  'PM2.5_3.0_mean',  'O3_20.0_max',  'TMP_23.0_max',  'RH_23.0_mean',  'TMP_25.0_mean',  'O3_24.0_max',  'hora_43.0_mean',  'RH_1.0_max',  'RH_21.0_min',  'RH_25.0_max',  'NO_8.0_mean',  'RH_24.0_max',  'TMP_0.0_min',  'O3_25.0_min',  'hora_33.0_mean',  'hora_21.0_mean',  'TMP_45.0_max',  'RH_2.0_max',  'NOX_8.0_max',  'O3_1.0_mean',  'TMP_min',  'RH_1.0_min',  'TMP_23.0_mean',  'TMP_23.0_min',  'O3_23.0_max',  'TMP_46.0_max',  'TMP_1.0_min',  'O3_3.0_mean',  'O3_2.0_max',  'RH_1.0_mean',  'RH_47.0_max',  'NO_7.0_max',  'RH_2.0_min',  'O3_44.0_mean',  'RH_0.0_mean',  'O3_1.0_min',  'O3_mean',  'RH_21.0_mean',  'RH_max',  'O3_max',  'O3_44.0_max',  'TMP_2.0_max',  'TMP_1.0_max',  'RH_45.0_max',  'TMP_24.0_max',  'RH_47.0_mean',  'O3_22.0_min',  'O3_47.0_min',  'hora_9.0_mean',  'NOX_6.0_mean',  'TMP_0.0_mean',  'O3_2.0_min',  'RH_46.0_min',  'RH_47.0_min',  'hora_9.0_max',  'O3_24.0_mean',  'RH_0.0_max',  'O3_47.0_mean',  'hora_12.0_mean',  'RH_48.0_mean',  'RH_mean_frcst_1',  'RH_mean_frcst_2',  'RH_mean_frcst_3',  'RH_mean_frcst_21',  'RH_mean_frcst_22',  'RH_mean_frcst_23',  'RH_mean_frcst_24',  'WSP_mean_frcst_2',  'WSP_mean_frcst_3',  'WSP_mean_frcst_13',  'WSP_mean_frcst_14',  'WSP_mean_frcst_15',  'WSP_mean_frcst_16',  'TMP_mean_frcst_1',  'TMP_mean_frcst_2',  'TMP_mean_frcst_3',  'TMP_mean_frcst_21',  'TMP_mean_frcst_22',  'TMP_mean_frcst_23',  'TMP_mean_frcst_24']
O3_corr.append("fecha")

# %% [markdown]
# Añadamos los datos de pronostico de las siguientes variables:

# %%
lista_frcst = ["RH_mean","WSP_mean","TMP_mean"]

# %%
for item in lista_frcst:
    for i in range(1, 25):
        col_name = str(item+"_frcst_"+str(i))
        data_hour_merge[col_name] = data_hour_merge[item].shift(i)

# %%
data_hour_merge = data_hour_merge[O3_corr]

# %%
#data_hour_merge = data_hour_merge.head(54)
#data_hour_merge = data_hour_merge.fillna(data_hour_merge.mean())

# %% [markdown]
# Guardemos:

# %%
data_hour_merge.to_csv(path_final,sep=',', encoding='utf-8',index=False)

# %%
data_hour_merge.head()
# Out:
#      O3_47.0_max  TMP_45.0_mean  O3_2.0_mean  RH_45.0_mean  RH_2.0_mean  \
# 803          NaN           24.0          NaN           0.0          0.0
# 802          NaN           24.0          NaN           0.0          0.0
# 801          NaN            NaN          NaN           NaN          0.0
# 800          NaN            NaN          NaN           NaN          0.0
# 799          NaN            NaN          NaN           NaN          0.0
#
#      RH_25.0_min  O3_23.0_mean  RH_44.0_min  RH_25.0_mean  RH_23.0_max  ...  \
# 803          6.0           NaN          0.0           7.0          8.0  ...
# 802          3.0           NaN          0.0           4.5          8.0  ...
# 801          3.0           NaN          NaN           3.0          6.0  ...
# 800          3.0           NaN          NaN           3.5          3.0  ...
# 799          4.0           NaN          NaN           5.5          4.0  ...
#
#      WSP_mean_frcst_15  WSP_mean_frcst_16  TMP_mean_frcst_1  TMP_mean_frcst_2  \
# 803                NaN                NaN               NaN               NaN
# 802                NaN                NaN              23.0               NaN
# 801                NaN                NaN              21.0              23.0
# 800                NaN                NaN              20.0              21.0
# 799                NaN                NaN              18.0              20.0
#
#      TMP_mean_frcst_3  TMP_mean_frcst_21  TMP_mean_frcst_22  \
# 803               NaN                NaN                NaN
# 802               NaN                NaN                NaN
# 801               NaN                NaN                NaN
# 800              23.0                NaN                NaN
# 799              21.0                NaN                NaN
#
#      TMP_mean_frcst_23  TMP_mean_frcst_24                fecha
# 803                NaN                NaN  2019-09-03 14:00:00
# 802                NaN                NaN  2019-09-03 13:00:00
# 801                NaN                NaN  2019-09-03 12:00:00
# 800                NaN                NaN  2019-09-03 11:00:00
# 799                NaN                NaN  2019-09-03 10:00:00
#
# [5 rows x 163 columns]

# %%
data_hour_merge.tail(-60).to_csv(path_final,sep=',', encoding='utf-8',index=False)
